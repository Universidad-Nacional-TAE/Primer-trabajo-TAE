# %%
import pandas as pd
import numpy as np
from pycaret.regression import *
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error as mse
import joblib

# %%
DfTrain = pd.read_csv('Volcamiento_train.csv', encoding = 'utf-8')
DfTest = pd.read_csv('Volcamiento_test.csv', encoding = 'utf-8')
Dfevalua = pd.read_csv('Volcamiento_evalua.csv', encoding = 'utf-8')

# %%
DfTest.head()
# Out:
#   FECHA_ACCIDENTE  Total
# 0      2018-01-01      1
# 1      2018-01-02      6
# 2      2018-01-03      4
# 3      2018-01-04      2
# 4      2018-01-05      1

# %%
df_festivos = pd.read_csv('festivosm.csv', encoding = 'utf-8', sep =';')

# %%
df_festivos['Fecha'] = pd.to_datetime(df_festivos['Fecha'], format="%m/%d/%Y")

# %%
DfTrain['FECHA_ACCIDENTE'] = pd.to_datetime(DfTrain['FECHA_ACCIDENTE'], format="%Y/%m/%d")
DfTest['FECHA_ACCIDENTE'] = pd.to_datetime(DfTest['FECHA_ACCIDENTE'], format="%Y/%m/%d")
Dfevalua['FECHA_ACCIDENTE'] = pd.to_datetime(Dfevalua['FECHA_ACCIDENTE'], format="%Y/%m/%d")

# %%
DfTrain['festivo'] = DfTrain['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)
DfTest['festivo'] = DfTest['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)
Dfevalua['festivo'] = Dfevalua['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)

# %%
DfTrain['Year'] = DfTrain['FECHA_ACCIDENTE'].dt.year
DfTrain['Month'] = DfTrain['FECHA_ACCIDENTE'].dt.month
DfTrain['DayMo'] = DfTrain['FECHA_ACCIDENTE'].dt.day
DfTrain['Dayw'] = DfTrain['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
DfTest['Year'] = DfTest['FECHA_ACCIDENTE'].dt.year
DfTest['Month'] = DfTest['FECHA_ACCIDENTE'].dt.month
DfTest['DayMo'] = DfTest['FECHA_ACCIDENTE'].dt.day
DfTest['Dayw'] = DfTest['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
Dfevalua['Year'] = Dfevalua['FECHA_ACCIDENTE'].dt.year
Dfevalua['Month'] = Dfevalua['FECHA_ACCIDENTE'].dt.month
Dfevalua['DayMo'] = Dfevalua['FECHA_ACCIDENTE'].dt.day
Dfevalua['Dayw'] = Dfevalua['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
DfTest.head()
# Out:
#   FECHA_ACCIDENTE  Total  festivo  Year  Month  DayMo       Dayw
# 0      2018-01-01      1        1  2018      1      1     Monday
# 1      2018-01-02      6        0  2018      1      2    Tuesday
# 2      2018-01-03      4        0  2018      1      3  Wednesday
# 3      2018-01-04      2        0  2018      1      4   Thursday
# 4      2018-01-05      1        0  2018      1      5     Friday

# %%
def quincena(f):
    z = []
    for i,j in zip(f['DayMo'],f['Dayw']):
        if (i in [15,30,31] and j in ['Monday','Tuesday', 'Thursday', 'Friday','Wednesday']):
            z.append(1)
        else:
            z.append(0)
    return z

# %%
DfTrain['Quincena'] = quincena(DfTrain)
DfTest['Quincena'] = quincena(DfTest)
Dfevalua['Quincena'] = quincena(Dfevalua)

# %%
variab = ['DayMo','Month','Year','festivo','Dayw','Total','Quincena']

# %%
DfTrain = DfTrain[variab]
DfTest = DfTest[variab]
Dfevalua = Dfevalua[variab]

# %%
Dfevalua.head()
# Out:
#    DayMo  Month  Year  festivo       Dayw  Total  Quincena
# 0      1      1  2020        1  Wednesday      3         0
# 1      2      1  2020        0   Thursday      7         0
# 2      3      1  2020        0     Friday      4         0
# 3      4      1  2020        0   Saturday      6         0
# 4      6      1  2020        1     Monday      4         0

# %% [markdown]
# ## One hot encoding y Modelo

# %%
DfTrain = pd.get_dummies(DfTrain)
DfTest = pd.get_dummies(DfTest)
Dfevalua = pd.get_dummies(Dfevalua)

# %%
num = list(DfTrain.columns.values)
num.remove('Total')

# %%
exp_reg101 = setup(data = DfTrain, target = 'Total',
                   numeric_features = num , normalize = True, session_id = 8301)
# Out:
# <style type="text/css">
# #T_208e4_row27_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_208e4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_208e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_208e4_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_208e4_row0_col1" class="data row0 col1" >8301</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_208e4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_208e4_row1_col1" class="data row1 col1" >Total</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_208e4_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_208e4_row2_col1" class="data row2 col1" >(1220, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_208e4_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_208e4_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_208e4_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_208e4_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_208e4_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_208e4_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_208e4_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_208e4_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_208e4_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_208e4_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_208e4_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_208e4_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_208e4_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_208e4_row9_col1" class="data row9 col1" >(853, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_208e4_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_208e4_row10_col1" class="data row10 col1" >(367, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_208e4_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_208e4_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_208e4_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_208e4_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_208e4_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_208e4_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_208e4_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_208e4_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_208e4_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_208e4_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_208e4_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_208e4_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_208e4_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_208e4_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_208e4_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_208e4_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_208e4_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_208e4_row19_col1" class="data row19 col1" >520a</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_208e4_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_208e4_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_208e4_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_208e4_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_208e4_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_208e4_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_208e4_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_208e4_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_208e4_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_208e4_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_208e4_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_208e4_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_208e4_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_208e4_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_208e4_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_208e4_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_208e4_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_208e4_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_208e4_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_208e4_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_208e4_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_208e4_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_208e4_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_06e99_ th {
#   text-align: left;
# }
# #T_06e99_row0_col0, #T_06e99_row0_col1, #T_06e99_row0_col2, #T_06e99_row0_col3, #T_06e99_row0_col6, #T_06e99_row1_col0, #T_06e99_row1_col1, #T_06e99_row1_col2, #T_06e99_row1_col3, #T_06e99_row1_col4, #T_06e99_row1_col6, #T_06e99_row2_col0, #T_06e99_row2_col1, #T_06e99_row2_col2, #T_06e99_row2_col3, #T_06e99_row2_col4, #T_06e99_row2_col6, #T_06e99_row3_col0, #T_06e99_row3_col1, #T_06e99_row3_col2, #T_06e99_row3_col3, #T_06e99_row3_col4, #T_06e99_row3_col6, #T_06e99_row4_col0, #T_06e99_row4_col1, #T_06e99_row4_col2, #T_06e99_row4_col3, #T_06e99_row4_col4, #T_06e99_row4_col6, #T_06e99_row5_col0, #T_06e99_row5_col4, #T_06e99_row6_col0, #T_06e99_row6_col1, #T_06e99_row6_col2, #T_06e99_row6_col3, #T_06e99_row6_col4, #T_06e99_row6_col6, #T_06e99_row7_col0, #T_06e99_row7_col1, #T_06e99_row7_col2, #T_06e99_row7_col3, #T_06e99_row7_col4, #T_06e99_row7_col6, #T_06e99_row8_col0, #T_06e99_row8_col1, #T_06e99_row8_col2, #T_06e99_row8_col3, #T_06e99_row8_col4, #T_06e99_row8_col6, #T_06e99_row9_col0, #T_06e99_row9_col1, #T_06e99_row9_col2, #T_06e99_row9_col3, #T_06e99_row9_col4, #T_06e99_row9_col6, #T_06e99_row10_col0, #T_06e99_row10_col1, #T_06e99_row10_col2, #T_06e99_row10_col3, #T_06e99_row10_col4, #T_06e99_row10_col6, #T_06e99_row11_col0, #T_06e99_row11_col1, #T_06e99_row11_col2, #T_06e99_row11_col3, #T_06e99_row11_col4, #T_06e99_row11_col6, #T_06e99_row12_col0, #T_06e99_row12_col1, #T_06e99_row12_col2, #T_06e99_row12_col3, #T_06e99_row12_col4, #T_06e99_row12_col6, #T_06e99_row13_col0, #T_06e99_row13_col1, #T_06e99_row13_col2, #T_06e99_row13_col3, #T_06e99_row13_col4, #T_06e99_row13_col6, #T_06e99_row14_col0, #T_06e99_row14_col1, #T_06e99_row14_col2, #T_06e99_row14_col3, #T_06e99_row14_col4, #T_06e99_row14_col6, #T_06e99_row15_col0, #T_06e99_row15_col1, #T_06e99_row15_col2, #T_06e99_row15_col3, #T_06e99_row15_col4, #T_06e99_row15_col6, #T_06e99_row16_col0, #T_06e99_row16_col1, #T_06e99_row16_col2, #T_06e99_row16_col3, #T_06e99_row16_col4, #T_06e99_row16_col6, #T_06e99_row17_col0, #T_06e99_row17_col1, #T_06e99_row17_col2, #T_06e99_row17_col3, #T_06e99_row17_col4, #T_06e99_row17_col6 {
#   text-align: left;
# }
# #T_06e99_row0_col4, #T_06e99_row0_col5, #T_06e99_row1_col5, #T_06e99_row2_col5, #T_06e99_row3_col5, #T_06e99_row4_col5, #T_06e99_row5_col1, #T_06e99_row5_col2, #T_06e99_row5_col3, #T_06e99_row5_col5, #T_06e99_row5_col6, #T_06e99_row6_col5, #T_06e99_row7_col5, #T_06e99_row8_col5, #T_06e99_row9_col5, #T_06e99_row10_col5, #T_06e99_row11_col5, #T_06e99_row12_col5, #T_06e99_row13_col5, #T_06e99_row14_col5, #T_06e99_row15_col5, #T_06e99_row16_col5, #T_06e99_row17_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_06e99_row0_col7, #T_06e99_row1_col7, #T_06e99_row3_col7, #T_06e99_row4_col7, #T_06e99_row5_col7, #T_06e99_row6_col7, #T_06e99_row7_col7, #T_06e99_row8_col7, #T_06e99_row9_col7, #T_06e99_row10_col7, #T_06e99_row11_col7, #T_06e99_row12_col7, #T_06e99_row13_col7, #T_06e99_row14_col7, #T_06e99_row15_col7, #T_06e99_row16_col7, #T_06e99_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_06e99_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_06e99_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06e99_level0_row0" class="row_heading level0 row0" >br</th>
#       <td id="T_06e99_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_06e99_row0_col1" class="data row0 col1" >1.7961</td>
#       <td id="T_06e99_row0_col2" class="data row0 col2" >5.7829</td>
#       <td id="T_06e99_row0_col3" class="data row0 col3" >2.3922</td>
#       <td id="T_06e99_row0_col4" class="data row0 col4" >0.0231</td>
#       <td id="T_06e99_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_06e99_row0_col6" class="data row0 col6" >0.6623</td>
#       <td id="T_06e99_row0_col7" class="data row0 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_06e99_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_06e99_row1_col0" class="data row1 col0" >Linear Regression</td>
#       <td id="T_06e99_row1_col1" class="data row1 col1" >1.7994</td>
#       <td id="T_06e99_row1_col2" class="data row1 col2" >5.7780</td>
#       <td id="T_06e99_row1_col3" class="data row1 col3" >2.3917</td>
#       <td id="T_06e99_row1_col4" class="data row1 col4" >0.0230</td>
#       <td id="T_06e99_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_06e99_row1_col6" class="data row1 col6" >0.6587</td>
#       <td id="T_06e99_row1_col7" class="data row1 col7" >1.3840</td>
#     </tr>
#     <tr>
#       <th id="T_06e99_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_06e99_row2_col0" class="data row2 col0" >Ridge Regression</td>
#       <td id="T_06e99_row2_col1" class="data row2 col1" >1.7992</td>
#       <td id="T_06e99_row2_col2" class="data row2 col2" >5.8054</td>
#       <td id="T_06e99_row2_col3" class="data row2 col3" >2.3972</td>
#       <td id="T_06e99_row2_col4" class="data row2 col4" >0.0185</td>
#       <td id="T_06e99_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_06e99_row2_col6" class="data row2 col6" >0.6606</td>
#       <td id="T_06e99_row2_col7" class="data row2 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_06e99_level0_row3" class="row_heading level0 row3" >lar</th>
#       <td id="T_06e99_row3_col0" class="data row3 col0" >Least Angle Regression</td>
#       <td id="T_06e99_row3_col1" class="data row3 col1" >1.7992</td>
#       <td id="T_06e99_row3_col2" class="data row3 col2" >5.8057</td>
#       <td id="T_06e99_row3_col3" class="data row3 col3" >2.3973</td>
#       <td id="T_06e99_row3_col4" class="data row3 col4" >0.0185</td>
#       <td id="T_06e99_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_06e99_row3_col6" class="data row3 col6" >0.6606</td>
#       <td id="T_06e99_row3_col7" class="data row3 col7" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_06e99_level0_row4" class="row_heading level0 row4" >huber</th>
#       <td id="T_06e99_row4_col0" class="data row4 col0" >Huber Regressor</td>
#       <td id="T_06e99_row4_col1" class="data row4 col1" >1.7579</td>
#       <td id="T_06e99_row4_col2" class="data row4 col2" >5.9006</td>
#       <td id="T_06e99_row4_col3" class="data row4 col3" >2.4144</td>
#       <td id="T_06e99_row4_col4" class="data row4 col4" >0.0057</td>
#       <td id="T_06e99_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_06e99_row4_col6" class="data row4 col6" >0.5966</td>
#       <td id="T_06e99_row4_col7" class="data row4 col7" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_06e99_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_06e99_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_06e99_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_06e99_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_06e99_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_06e99_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_06e99_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_06e99_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_06e99_row5_col7" class="data row5 col7" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_06e99_level0_row6" class="row_heading level0 row6" >omp</th>
#       <td id="T_06e99_row6_col0" class="data row6 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_06e99_row6_col1" class="data row6 col1" >1.8419</td>
#       <td id="T
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False)

# %%
rfj = create_model('rf')
# Out:
# <style type="text/css">
# #T_66be4_row10_col0, #T_66be4_row10_col1, #T_66be4_row10_col2, #T_66be4_row10_col3, #T_66be4_row10_col4, #T_66be4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_66be4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66be4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66be4_row0_col0" class="data row0 col0" >1.6780</td>
#       <td id="T_66be4_row0_col1" class="data row0 col1" >4.2587</td>
#       <td id="T_66be4_row0_col2" class="data row0 col2" >2.0637</td>
#       <td id="T_66be4_row0_col3" class="data row0 col3" >-0.0987</td>
#       <td id="T_66be4_row0_col4" class="data row0 col4" >-0.0000</td>
#       <td id="T_66be4_row0_col5" class="data row0 col5" >0.7340</td>
#     </tr>
#     <tr>
#       <th id="T_66be4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66be4_row1_col0" class="data row1 col0" >2.0760</td>
#       <td id="T_66be4_row1_col1" class="data row1 col1" >6.4241</td>
#       <td id="T_66be4_row1_col2" class="data row1 col2" >2.5346</td>
#       <td id="T_66be4_row1_col3" class="data row1 col3" >-0.0053</td>
#       <td id="T_66be4_row1_col4" class="data row1 col4" >-0.0000</td>
#       <td id="T_66be4_row1_col5" class="data row1 col5" >0.7104</td>
#     </tr>
#     <tr>
#       <th id="T_66be4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_66be4_row2_col0" class="data row2 col0" >1.8673</td>
#       <td id="T_66be4_row2_col1" class="data row2 col1" >5.0520</td>
#       <td id="T_66be4_row2_col2" class="data row2 col2" >2.2477</td>
#       <td id="T_66be4_row2_col3" class="data row2 col3" >-0.0272</td>
#       <td id="T_66be4_row2_col4" class="data row2 col4" >-0.0000</td>
#       <td id="T_66be4_row2_col5" class="data row2 col5" >0.7548</td>
#     </tr>
#     <tr>
#       <th id="T_66be4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_66be4_row3_col0" class="data row3 col0" >1.9981</td>
#       <td id="T_66be4_row3_col1" class="data row3 col1" >6.4850</td>
#       <td id="T_66be4_row3_col2" class="data row3 col2" >2.5466</td>
#       <td id="T_66be4_row3_col3" class="data row3 col3" >-0.0434</td>
#       <td id="T_66be4_row3_col4" class="data row3 col4" >-0.0000</td>
#       <td id="T_66be4_row3_col5" class="data row3 col5" >0.7225</td>
#     </tr>
#     <tr>
#       <th id="T_66be4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_66be4_row4_col0" class="data row4 col0" >1.8940</td>
#       <td id="T_66be4_row4_col1" class="data row4 col1" >6.8176</td>
#       <td id="T_66be4_row4_col2" class="data row4 col2" >2.6111</td>
#       <td id="T_66be4_row4_col3" class="data row4 col3" >-0.1553</td>
#       <td id="T_66be4_row4_col4" class="data row4 col4" >-0.0000</td>
#       <td id="T_66be4_row4_col5" class="data row4 col5" >0.6965</td>
#     </tr>
#     <tr>
#       <th id="T_66be4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_66be4_row5_col0" class="data row5 col0" >1.8001</td>
#       <td id="T_66be4_row5_col1" class="data row5 col1" >6.2332</td>
#       <td id="T_66be4_row5_col2" class="data row5 col2" >2.4966</td>
#       <td id="T_66be4_row5_col3" class="data row5 col3" >-0.0138</td>
#       <td id="T_66be4_row5_col4" class="data row5 col4" >-0.0000</td>
#       <td id="T_66be4_row5_col5" class="data row5 col5" >0.5916</td>
#     </tr>
#     <tr>
#       <th id="T_66be4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_66be4_row6_col0" class="data row6 col0" >2.2587</td>
#       <td id="T_66be4_row6_col1" class="data row6 col1" >8.7216</td>
#       <td id="T_66be4_row6_col2" class="data row6 col2" >2.9532</td>
#       <td id="T_66be4_row6_col3" class="data row6 col3" >-0.2612</td>
#       <td id="T_66be4_row6_col4" class="data row6 col4" >-0.0000</td>
#       <td id="T_66be4_row6_col5" class="data row6 col5" >0.8231</td>
#     </tr>
#     <tr>
#       <th id="T_66be4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_66be4_row7_col0" class="data row7 col0" >2.1061</td>
#       <td id="T_66be4_row7_col1" class="data row7 col1" >6.9438</td>
#       <td id="T_66be4_row7_col2" class="data row7 col2" >2.6351</td>
#       <td id="T_66be4_row7_col3" class="data row7 col3" >-0.1434</td>
#       <td id="T_66be4_row7_col4" class="data row7 col4" >-0.0000</td>
#       <td id="T_66be4_row7_col5" class="data row7 col5" >0.6365</td>
#     </tr>
#     <tr>
#       <th id="T_66be4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_66be4_row8_col0" class="data row8 col0" >1.9549</td>
#       <td id="T_66be4_row8_col1" class="data row8 col1" >5.7424</td>
#       <td id="T_66be4_row8_col2" class="data row8 col2" >2.3963</td>
#       <td id="T_66be4_row8_col3" class="data row8 col3" >-0.2745</td>
#       <td id="T_66be4_row8_col4" class="data row8 col4" >-0.0000</td>
#       <td id="T_66be4_row8_col5" class="data row8 col5" >0.7179</td>
#     </tr>
#     <tr>
#       <th id="T_66be4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_66be4_row9_col0" class="data row9 col0" >2.0578</td>
#       <td id="T_66be4_row9_col1" class="data row9 col1" >8.8763</td>
#       <td id="T_66be4_row9_col2" class="data row9 col2" >2.9793</td>
#       <td id="T_66be4_row9_col3" class="data row9 col3" >-0.0747</td>
#       <td id="T_66be4_row9_col4" class="data row9 col4" >-0.0000</td>
#       <td id="T_66be4_row9_col5" class="data row9 col5" >0.8668</td>
#     </tr>
#     <tr>
#       <th id="T_66be4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_66be4_row10_col0" class="data row10 col0" >1.9691</td>
#       <td id="T_66be4_row10_col1" class="data row10 col1" >6.5555</td>
#       <td id="T_66be4_row10_col2" class="data row10 col2" >2.5464</td>
#       <td id="T_66be4_row10_col3" class="data row10 col3" >-0.1098</td>
#       <td id="T_66be4_row10_col4" class="data row10 col4" >0.0000</td>
#       <td id="T_66be4_row10_col5" class="data row10 col5" >0.7254</td>
#     </tr>
#     <tr>
#       <th id="T_66be4_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_66be4_row11_col0" class="data row11 col0" >0.1588</td>
#       <td id="T_66be4_row11_col1" class="data row11 col1" >1.3646</td>
#       <td id="T_66be4_row11_col2" class="data row11 col2" >0.2669</td>
#       <td id="T_66be4_row11_col3" class="data row11 col3" >0.0927</td>
#       <td id="T_66be4_row11_col4" class="data row11 col4" >0.0000</td>
#       <td id="T_66be4_row11_col5" class="data row11 col5" >0.0758</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_rfj = tune_model(rfj)
# Out:
# <style type="text/css">
# #T_58127_row10_col0, #T_58127_row10_col1, #T_58127_row10_col2, #T_58127_row10_col3, #T_58127_row10_col4, #T_58127_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_58127_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58127_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_58127_row0_col0" class="data row0 col0" >1.5731</td>
#       <td id="T_58127_row0_col1" class="data row0 col1" >3.6532</td>
#       <td id="T_58127_row0_col2" class="data row0 col2" >1.9113</td>
#       <td id="T_58127_row0_col3" class="data row0 col3" >0.0575</td>
#       <td id="T_58127_row0_col4" class="data row0 col4" >-0.0000</td>
#       <td id="T_58127_row0_col5" class="data row0 col5" >0.6962</td>
#     </tr>
#     <tr>
#       <th id="T_58127_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_58127_row1_col0" class="data row1 col0" >1.9973</td>
#       <td id="T_58127_row1_col1" class="data row1 col1" >5.9715</td>
#       <td id="T_58127_row1_col2" class="data row1 col2" >2.4437</td>
#       <td id="T_58127_row1_col3" class="data row1 col3" >0.0655</td>
#       <td id="T_58127_row1_col4" class="data row1 col4" >-0.0000</td>
#       <td id="T_58127_row1_col5" class="data row1 col5" >0.6957</td>
#     </tr>
#     <tr>
#       <th id="T_58127_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_58127_row2_col0" class="data row2 col0" >1.6497</td>
#       <td id="T_58127_row2_col1" class="data row2 col1" >4.5566</td>
#       <td id="T_58127_row2_col2" class="data row2 col2" >2.1346</td>
#       <td id="T_58127_row2_col3" class="data row2 col3" >0.0736</td>
#       <td id="T_58127_row2_col4" class="data row2 col4" >-0.0000</td>
#       <td id="T_58127_row2_col5" class="data row2 col5" >0.6763</td>
#     </tr>
#     <tr>
#       <th id="T_58127_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_58127_row3_col0" class="data row3 col0" >1.8348</td>
#       <td id="T_58127_row3_col1" class="data row3 col1" >5.8149</td>
#       <td id="T_58127_row3_col2" class="data row3 col2" >2.4114</td>
#       <td id="T_58127_row3_col3" class="data row3 col3" >0.0644</td>
#       <td id="T_58127_row3_col4" class="data row3 col4" >-0.0000</td>
#       <td id="T_58127_row3_col5" class="data row3 col5" >0.6572</td>
#     </tr>
#     <tr>
#       <th id="T_58127_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_58127_row4_col0" class="data row4 col0" >1.7195</td>
#       <td id="T_58127_row4_col1" class="data row4 col1" >5.8198</td>
#       <td id="T_58127_row4_col2" class="data row4 col2" >2.4124</td>
#       <td id="T_58127_row4_col3" class="data row4 col3" >0.0138</td>
#       <td id="T_58127_row4_col4" class="data row4 col4" >-0.0000</td>
#       <td id="T_58127_row4_col5" class="data row4 col5" >0.6589</td>
#     </tr>
#     <tr>
#       <th id="T_58127_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_58127_row5_col0" class="data row5 col0" >1.7418</td>
#       <td id="T_58127_row5_col1" class="data row5 col1" >5.8648</td>
#       <td id="T_58127_row5_col2" class="data row5 col2" >2.4217</td>
#       <td id="T_58127_row5_col3" class="data row5 col3" >0.0461</td>
#       <td id="T_58127_row5_col4" class="data row5 col4" >-0.0000</td>
#       <td id="T_58127_row5_col5" class="data row5 col5" >0.5559</td>
#     </tr>
#     <tr>
#       <th id="T_58127_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_58127_row6_col0" class="data row6 col0" >1.9736</td>
#       <td id="T_58127_row6_col1" class="data row6 col1" >7.1482</td>
#       <td id="T_58127_row6_col2" class="data row6 col2" >2.6736</td>
#       <td id="T_58127_row6_col3" class="data row6 col3" >-0.0337</td>
#       <td id="T_58127_row6_col4" class="data row6 col4" >-0.0000</td>
#       <td id="T_58127_row6_col5" class="data row6 col5" >0.7338</td>
#     </tr>
#     <tr>
#       <th id="T_58127_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_58127_row7_col0" class="data row7 col0" >1.9911</td>
#       <td id="T_58127_row7_col1" class="data row7 col1" >6.5334</td>
#       <td id="T_58127_row7_col2" class="data row7 col2" >2.5561</td>
#       <td id="T_58127_row7_col3" class="data row7 col3" >-0.0758</td>
#       <td id="T_58127_row7_col4" class="data row7 col4" >-0.0000</td>
#       <td id="T_58127_row7_col5" class="data row7 col5" >0.6152</td>
#     </tr>
#     <tr>
#       <th id="T_58127_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_58127_row8_col0" class="data row8 col0" >1.6872</td>
#       <td id="T_58127_row8_col1" class="data row8 col1" >4.3454</td>
#       <td id="T_58127_row8_col2" class="data row8 col2" >2.0846</td>
#       <td id="T_58127_row8_col3" class="data row8 col3" >0.0356</td>
#       <td id="T_58127_row8_col4" class="data row8 col4" >-0.0000</td>
#       <td id="T_58127_row8_col5" class="data row8 col5" >0.5797</td>
#     </tr>
#     <tr>
#       <th id="T_58127_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_58127_row9_col0" class="data row9 col0" >1.8174</td>
#       <td id="T_58127_row9_col1" class="data row9 col1" >7.9274</td>
#       <td id="T_58127_row9_col2" class="data row9 col2" >2.8156</td>
#       <td id="T_58127_row9_col3" class="data row9 col3" >0.0402</td>
#       <td id="T_58127_row9_col4" class="data row9 col4" >-0.0000</td>
#       <td id="T_58127_row9_col5" class="data row9 col5" >0.7742</td>
#     </tr>
#     <tr>
#       <th id="T_58127_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_58127_row10_col0" class="data row10 col0" >1.7985</td>
#       <td id="T_58127_row10_col1" class="data row10 col1" >5.7635</td>
#       <td id="T_58127_row10_col2" class="data row10 col2" >2.3865</td>
#       <td id="T_58127_row10_col3" class="data row10 col3" >0.0287</td>
#       <td id="T_58127_row10_col4" class="data row10 col4" >0.0000</td>
#       <td id="T_58127_row10_col5" class="data row10 col5" >0.6643</td>
#     </tr>
#     <tr>
#       <th id="T_58127_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_58127_row11_col0" class="data row11 col0" >0.1427</td>
#       <td id="T_58127_row11_col1" class="data row11 col1" >1.2318</td>
#       <td id="T_58127_row11_col2" class="data row11 col2" >0.2611</td>
#       <td id="T_58127_row11_col3" class="data row11 col3" >0.0458</td>
#       <td id="T_58127_row11_col4" class="data row11 col4" >0.0000</td>
#       <td id="T_58127_row11_col5" class="data row11 col5" >0.0636</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_rfj
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='log2', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.005,
#                       min_impurity_split=None, min_samples_leaf=2,
#                       min_samples_split=10, min_weight_fraction_leaf=0.0,
#                       n_estimators=190, n_jobs=-1, oob_score=False,
#                       random_state=8301, verbose=0, warm_start=False)

# %%
predict_model(tuned_rfj)
# Out:
# <style type="text/css">
# </style>
# <table id="T_713d6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_713d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_713d6_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_713d6_row0_col1" class="data row0 col1" >1.9288</td>
#       <td id="T_713d6_row0_col2" class="data row0 col2" >6.4612</td>
#       <td id="T_713d6_row0_col3" class="data row0 col3" >2.5419</td>
#       <td id="T_713d6_row0_col4" class="data row0 col4" >0.0675</td>
#       <td id="T_713d6_row0_col5" class="data row0 col5" >0.4809</td>
#       <td id="T_713d6_row0_col6" class="data row0 col6" >0.7321</td>
#     </tr>
#   </tbody>
# </table>
#         DayMo     Month      Year   festivo  Quincena  Dayw_Friday  \
# 0    1.605123  0.905161  1.214362 -0.230405  4.050699    -0.420181
# 1   -0.874236  0.028104  0.239902 -0.230405 -0.246871     2.379929
# 2   -1.212331 -1.141305 -0.734557 -0.230405 -0.246871    -0.420181
# 3    0.703538 -0.556601 -0.734557 -0.230405 -0.246871     2.379929
# 4   -1.437727 -1.433658 -0.734557 -0.230405 -0.246871    -0.420181
# ..        ...       ...       ...       ...       ...          ...
# 362 -0.423444  0.905161 -0.734557  4.340186 -0.246871    -0.420181
# 363 -1.099633  0.028104  0.239902 -0.230405 -0.246871    -0.420181
# 364  0.703538  1.489866 -1.709017 -0.230405 -0.246871    -0.420181
# 365 -0.085349 -0.556601  0.239902 -0.230405 -0.246871    -0.420181
# 366 -1.099633  0.612809 -1.709017 -0.230405 -0.246871    -0.420181
#
#      Dayw_Monday  Dayw_Saturday  Dayw_Sunday  Dayw_Thursday  Dayw_Tuesday  \
# 0       2.347648      -0.400680    -0.398707      -0.398707     -0.408527
# 1      -0.425958      -0.400680    -0.398707      -0.398707     -0.408527
# 2      -0.425958      -0.400680    -0.398707       2.508106     -0.408527
# 3      -0.425958      -0.400680    -0.398707      -0.398707     -0.408527
# 4      -0.425958      -0.400680    -0.398707      -0.398707      2.447816
# ..           ...            ...          ...            ...           ...
# 362     2.347648      -0.400680    -0.398707      -0.398707     -0.408527
# 363    -0.425958      -0.400680    -0.398707      -0.398707     -0.408527
# 364     2.347648      -0.400680    -0.398707      -0.398707     -0.408527
# 365    -0.425958      -0.400680     2.508106      -0.398707     -0.408527
# 366    -0.425958       2.495759    -0.398707      -0.398707     -0.408527
#
#      Dayw_Wednesday Total     Label
# 0         -0.404612     1  4.992981
# 1         -0.404612     1  4.492951
# 2         -0.404612     2  4.200570
# 3         -0.404612     5  4.114639
# 4         -0.404612     1  3.579218
# ..              ...   ...       ...
# 362       -0.404612     1  4.132985
# 363        2.471504     4  4.507517
# 364       -0.404612     3  3.297429
# 365       -0.404612     3  3.238361
# 366       -0.404612     2  3.241626
#
# [367 rows x 14 columns]

# %%
labeltr = DfTrain['Total']
labeltest = DfTest['Total']
DfTrain = DfTrain.drop('Total', axis = 1)
DfTest = DfTest.drop('Total', axis = 1)

# %%
forest = tuned_rfj.fit(DfTrain,labeltr)

# %% [markdown]
# ## Rmse entrenamiento

# %%
ypredTrain = forest.predict(DfTrain)

# %%
(mse(ypredTrain,labeltr))**(1/2)
# Out:
# 2.34690415274137

# %% [markdown]
# ## Rmse Test

# %%
ypredTest = forest.predict(DfTest)

# %%
(mse(ypredTest,labeltest))**(1/2)
# Out:
# 2.5265546845240756

# %% [markdown]
# ## Rmse Evaluación

# %%
labelevalua = Dfevalua['Total']

# %%
Dfevalua = Dfevalua.drop(['Total'], axis = 1)

# %%
yevalua = forest.predict(Dfevalua)

# %%
(mse(yevalua,labelevalua))**(1/2)
# Out:
# 3.235968430492066

# %% [markdown]
# ## Se guarda modelo

# %%
joblib.dump(forest, 'modelo_Volcamiento_entrenado.pkl') # Se guarda el modelo.
# Out:
# ['modelo_Volcamiento_entrenado.pkl']
