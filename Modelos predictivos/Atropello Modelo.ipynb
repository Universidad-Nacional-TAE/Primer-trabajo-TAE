# %%
import pandas as pd
import numpy as np
from pycaret.regression import *
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error as mse
import joblib

# %%
DfTrain = pd.read_csv('Atropello_train.csv', encoding = 'utf-8')
DfTest = pd.read_csv('Atropello_test.csv', encoding = 'utf-8')
Dfevalua = pd.read_csv('Atropello_evalua.csv', encoding = 'utf-8')

# %%
DfTest.head()
# Out:
#   FECHA_ACCIDENTE  Total
# 0      2018-01-01      8
# 1      2018-01-02      6
# 2      2018-01-03     14
# 3      2018-01-04      8
# 4      2018-01-05     10

# %%
df_festivos = pd.read_csv('festivosm.csv', encoding = 'utf-8', sep =';')

# %%
df_festivos['Fecha'] = pd.to_datetime(df_festivos['Fecha'], format="%m/%d/%Y")

# %%
DfTrain['FECHA_ACCIDENTE'] = pd.to_datetime(DfTrain['FECHA_ACCIDENTE'], format="%Y/%m/%d")
DfTest['FECHA_ACCIDENTE'] = pd.to_datetime(DfTest['FECHA_ACCIDENTE'], format="%Y/%m/%d")
Dfevalua['FECHA_ACCIDENTE'] = pd.to_datetime(Dfevalua['FECHA_ACCIDENTE'], format="%Y/%m/%d")

# %%
DfTrain['festivo'] = DfTrain['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)
DfTest['festivo'] = DfTest['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)
Dfevalua['festivo'] = Dfevalua['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)

# %%
DfTrain['Year'] = DfTrain['FECHA_ACCIDENTE'].dt.year
DfTrain['Month'] = DfTrain['FECHA_ACCIDENTE'].dt.month
DfTrain['DayMo'] = DfTrain['FECHA_ACCIDENTE'].dt.day
DfTrain['Dayw'] = DfTrain['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
DfTest['Year'] = DfTest['FECHA_ACCIDENTE'].dt.year
DfTest['Month'] = DfTest['FECHA_ACCIDENTE'].dt.month
DfTest['DayMo'] = DfTest['FECHA_ACCIDENTE'].dt.day
DfTest['Dayw'] = DfTest['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
Dfevalua['Year'] = Dfevalua['FECHA_ACCIDENTE'].dt.year
Dfevalua['Month'] = Dfevalua['FECHA_ACCIDENTE'].dt.month
Dfevalua['DayMo'] = Dfevalua['FECHA_ACCIDENTE'].dt.day
Dfevalua['Dayw'] = Dfevalua['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
DfTest.head()
# Out:
#   FECHA_ACCIDENTE  Total  festivo  Year  Month  DayMo       Dayw
# 0      2018-01-01      8        1  2018      1      1     Monday
# 1      2018-01-02      6        0  2018      1      2    Tuesday
# 2      2018-01-03     14        0  2018      1      3  Wednesday
# 3      2018-01-04      8        0  2018      1      4   Thursday
# 4      2018-01-05     10        0  2018      1      5     Friday

# %%
def quincena(f):
    z = []
    for i,j in zip(f['DayMo'],f['Dayw']):
        if (i in [15,30,31] and j in ['Monday','Tuesday', 'Thursday', 'Friday','Wednesday']):
            z.append(1)
        else:
            z.append(0)
    return z

# %%
DfTrain['Quincena'] = quincena(DfTrain)
DfTest['Quincena'] = quincena(DfTest)
Dfevalua['Quincena'] = quincena(Dfevalua)

# %%
variab = ['DayMo','Month','Year','festivo','Dayw','Total','Quincena']

# %%
DfTrain = DfTrain[variab]
DfTest = DfTest[variab]
Dfevalua = Dfevalua[variab]

# %%
Dfevalua.head()
# Out:
#    DayMo  Month  Year  festivo       Dayw  Total  Quincena
# 0      1      1  2020        1  Wednesday     12         0
# 1      2      1  2020        0   Thursday      7         0
# 2      3      1  2020        0     Friday     12         0
# 3      4      1  2020        0   Saturday      5         0
# 4      5      1  2020        0     Sunday     10         0

# %% [markdown]
# ## One hot encoding y Modelo

# %%
DfTrain = pd.get_dummies(DfTrain)
DfTest = pd.get_dummies(DfTest)
Dfevalua = pd.get_dummies(Dfevalua)

# %%
num = list(DfTrain.columns.values)
num.remove('Total')

# %%
exp_reg101 = setup(data = DfTrain, target = 'Total',
                   numeric_features = num , normalize = True, session_id = 8301)
# Out:
# <style type="text/css">
# #T_4c579_row27_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4c579_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c579_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c579_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_4c579_row0_col1" class="data row0 col1" >8301</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c579_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4c579_row1_col1" class="data row1 col1" >Total</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4c579_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_4c579_row2_col1" class="data row2 col1" >(1275, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4c579_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_4c579_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4c579_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_4c579_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4c579_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_4c579_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4c579_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_4c579_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4c579_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_4c579_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4c579_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_4c579_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4c579_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_4c579_row9_col1" class="data row9 col1" >(892, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4c579_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_4c579_row10_col1" class="data row10 col1" >(383, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4c579_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_4c579_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4c579_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_4c579_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4c579_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_4c579_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4c579_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_4c579_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4c579_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_4c579_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4c579_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_4c579_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4c579_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_4c579_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4c579_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_4c579_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4c579_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_4c579_row19_col1" class="data row19 col1" >12a9</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4c579_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_4c579_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4c579_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_4c579_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_4c579_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_4c579_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_4c579_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_4c579_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_4c579_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_4c579_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_4c579_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_4c579_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_4c579_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_4c579_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_4c579_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_4c579_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_4c579_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_4c579_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_4c579_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_4c579_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4c579_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_4c579_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_4c579_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_45000_ th {
#   text-align: left;
# }
# #T_45000_row0_col0, #T_45000_row0_col1, #T_45000_row0_col5, #T_45000_row0_col6, #T_45000_row1_col0, #T_45000_row1_col1, #T_45000_row1_col2, #T_45000_row1_col3, #T_45000_row1_col4, #T_45000_row1_col5, #T_45000_row1_col6, #T_45000_row2_col0, #T_45000_row2_col1, #T_45000_row2_col2, #T_45000_row2_col3, #T_45000_row2_col4, #T_45000_row2_col5, #T_45000_row2_col6, #T_45000_row3_col0, #T_45000_row3_col2, #T_45000_row3_col3, #T_45000_row3_col4, #T_45000_row4_col0, #T_45000_row4_col1, #T_45000_row4_col2, #T_45000_row4_col3, #T_45000_row4_col4, #T_45000_row4_col5, #T_45000_row4_col6, #T_45000_row5_col0, #T_45000_row5_col1, #T_45000_row5_col2, #T_45000_row5_col3, #T_45000_row5_col4, #T_45000_row5_col5, #T_45000_row5_col6, #T_45000_row6_col0, #T_45000_row6_col1, #T_45000_row6_col2, #T_45000_row6_col3, #T_45000_row6_col4, #T_45000_row6_col5, #T_45000_row6_col6, #T_45000_row7_col0, #T_45000_row7_col1, #T_45000_row7_col2, #T_45000_row7_col3, #T_45000_row7_col4, #T_45000_row7_col5, #T_45000_row7_col6, #T_45000_row8_col0, #T_45000_row8_col1, #T_45000_row8_col2, #T_45000_row8_col3, #T_45000_row8_col4, #T_45000_row8_col5, #T_45000_row8_col6, #T_45000_row9_col0, #T_45000_row9_col1, #T_45000_row9_col2, #T_45000_row9_col3, #T_45000_row9_col4, #T_45000_row9_col5, #T_45000_row9_col6, #T_45000_row10_col0, #T_45000_row10_col1, #T_45000_row10_col2, #T_45000_row10_col3, #T_45000_row10_col4, #T_45000_row10_col5, #T_45000_row10_col6, #T_45000_row11_col0, #T_45000_row11_col1, #T_45000_row11_col2, #T_45000_row11_col3, #T_45000_row11_col4, #T_45000_row11_col5, #T_45000_row11_col6, #T_45000_row12_col0, #T_45000_row12_col1, #T_45000_row12_col2, #T_45000_row12_col3, #T_45000_row12_col4, #T_45000_row12_col5, #T_45000_row12_col6, #T_45000_row13_col0, #T_45000_row13_col1, #T_45000_row13_col2, #T_45000_row13_col3, #T_45000_row13_col4, #T_45000_row13_col5, #T_45000_row13_col6, #T_45000_row14_col0, #T_45000_row14_col1, #T_45000_row14_col2, #T_45000_row14_col3, #T_45000_row14_col4, #T_45000_row14_col5, #T_45000_row14_col6, #T_45000_row15_col0, #T_45000_row15_col1, #T_45000_row15_col2, #T_45000_row15_col3, #T_45000_row15_col4, #T_45000_row15_col5, #T_45000_row15_col6, #T_45000_row16_col0, #T_45000_row16_col1, #T_45000_row16_col2, #T_45000_row16_col3, #T_45000_row16_col4, #T_45000_row16_col5, #T_45000_row16_col6, #T_45000_row17_col0, #T_45000_row17_col1, #T_45000_row17_col2, #T_45000_row17_col3, #T_45000_row17_col4, #T_45000_row17_col5, #T_45000_row17_col6, #T_45000_row18_col0, #T_45000_row18_col1, #T_45000_row18_col2, #T_45000_row18_col3, #T_45000_row18_col4, #T_45000_row18_col5, #T_45000_row18_col6 {
#   text-align: left;
# }
# #T_45000_row0_col2, #T_45000_row0_col3, #T_45000_row0_col4, #T_45000_row3_col1, #T_45000_row3_col5, #T_45000_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_45000_row0_col7, #T_45000_row1_col7, #T_45000_row2_col7, #T_45000_row3_col7, #T_45000_row4_col7, #T_45000_row5_col7, #T_45000_row6_col7, #T_45000_row8_col7, #T_45000_row9_col7, #T_45000_row10_col7, #T_45000_row11_col7, #T_45000_row12_col7, #T_45000_row13_col7, #T_45000_row14_col7, #T_45000_row15_col7, #T_45000_row16_col7, #T_45000_row17_col7, #T_45000_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_45000_row7_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_45000_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45000_level0_row0" class="row_heading level0 row0" >br</th>
#       <td id="T_45000_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_45000_row0_col1" class="data row0 col1" >2.9320</td>
#       <td id="T_45000_row0_col2" class="data row0 col2" >13.3499</td>
#       <td id="T_45000_row0_col3" class="data row0 col3" >3.6487</td>
#       <td id="T_45000_row0_col4" class="data row0 col4" >0.0894</td>
#       <td id="T_45000_row0_col5" class="data row0 col5" >0.3285</td>
#       <td id="T_45000_row0_col6" class="data row0 col6" >0.3351</td>
#       <td id="T_45000_row0_col7" class="data row0 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_45000_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_45000_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_45000_row1_col1" class="data row1 col1" >2.9282</td>
#       <td id="T_45000_row1_col2" class="data row1 col2" >13.3577</td>
#       <td id="T_45000_row1_col3" class="data row1 col3" >3.6499</td>
#       <td id="T_45000_row1_col4" class="data row1 col4" >0.0881</td>
#       <td id="T_45000_row1_col5" class="data row1 col5" >0.3283</td>
#       <td id="T_45000_row1_col6" class="data row1 col6" >0.3339</td>
#       <td id="T_45000_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_45000_level0_row2" class="row_heading level0 row2" >lar</th>
#       <td id="T_45000_row2_col0" class="data row2 col0" >Least Angle Regression</td>
#       <td id="T_45000_row2_col1" class="data row2 col1" >2.9282</td>
#       <td id="T_45000_row2_col2" class="data row2 col2" >13.3581</td>
#       <td id="T_45000_row2_col3" class="data row2 col3" >3.6500</td>
#       <td id="T_45000_row2_col4" class="data row2 col4" >0.0881</td>
#       <td id="T_45000_row2_col5" class="data row2 col5" >0.3283</td>
#       <td id="T_45000_row2_col6" class="data row2 col6" >0.3338</td>
#       <td id="T_45000_row2_col7" class="data row2 col7" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_45000_level0_row3" class="row_heading level0 row3" >huber</th>
#       <td id="T_45000_row3_col0" class="data row3 col0" >Huber Regressor</td>
#       <td id="T_45000_row3_col1" class="data row3 col1" >2.9281</td>
#       <td id="T_45000_row3_col2" class="data row3 col2" >13.3795</td>
#       <td id="T_45000_row3_col3" class="data row3 col3" >3.6522</td>
#       <td id="T_45000_row3_col4" class="data row3 col4" >0.0873</td>
#       <td id="T_45000_row3_col5" class="data row3 col5" >0.3272</td>
#       <td id="T_45000_row3_col6" class="data row3 col6" >0.3306</td>
#       <td id="T_45000_row3_col7" class="data row3 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_45000_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_45000_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_45000_row4_col1" class="data row4 col1" >2.9364</td>
#       <td id="T_45000_row4_col2" class="data row4 col2" >13.3946</td>
#       <td id="T_45000_row4_col3" class="data row4 col3" >3.6550</td>
#       <td id="T_45000_row4_col4" class="data row4 col4" >0.0855</td>
#       <td id="T_45000_row4_col5" class="data row4 col5" >0.3286</td>
#       <td id="T_45000_row4_col6" class="data row4 col6" >0.3346</td>
#       <td id="T_45000_row4_col7" class="data row4 col7" >1.7070</td>
#     </tr>
#     <tr>
#       <th id="T_45000_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_45000_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_45000_row5_col1" class="data row5 col1" >2.9628</td>
#       <td id="T_45000_row5_col2" class="data row5 col2" >13.8800</td>
#       <td id="T_45000_row5_col3" class="data row5 col3" >3.7186</td>
#       <td id="T_45000_row5_col4" class="data row5 col4" >0.0523</td>
#       <td id="T_45000_row5_col5" class="data row5 col5" >0.3362</td>
#       <td id="T_45000_row5_col6" class="data row5 col6" >0.3352</td>
#       <td id="T_45000_row5_col7" class="data row5 col7" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_45000_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False)

# %%
rfj = create_model('rf')
# Out:
# <style type="text/css">
# #T_7abbe_row10_col0, #T_7abbe_row10_col1, #T_7abbe_row10_col2, #T_7abbe_row10_col3, #T_7abbe_row10_col4, #T_7abbe_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7abbe_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7abbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7abbe_row0_col0" class="data row0 col0" >2.9662</td>
#       <td id="T_7abbe_row0_col1" class="data row0 col1" >13.9645</td>
#       <td id="T_7abbe_row0_col2" class="data row0 col2" >3.7369</td>
#       <td id="T_7abbe_row0_col3" class="data row0 col3" >0.0453</td>
#       <td id="T_7abbe_row0_col4" class="data row0 col4" >0.3097</td>
#       <td id="T_7abbe_row0_col5" class="data row0 col5" >0.2954</td>
#     </tr>
#     <tr>
#       <th id="T_7abbe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7abbe_row1_col0" class="data row1 col0" >2.9721</td>
#       <td id="T_7abbe_row1_col1" class="data row1 col1" >12.3998</td>
#       <td id="T_7abbe_row1_col2" class="data row1 col2" >3.5213</td>
#       <td id="T_7abbe_row1_col3" class="data row1 col3" >0.0582</td>
#       <td id="T_7abbe_row1_col4" class="data row1 col4" >0.3298</td>
#       <td id="T_7abbe_row1_col5" class="data row1 col5" >0.3456</td>
#     </tr>
#     <tr>
#       <th id="T_7abbe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7abbe_row2_col0" class="data row2 col0" >3.1524</td>
#       <td id="T_7abbe_row2_col1" class="data row2 col1" >15.0915</td>
#       <td id="T_7abbe_row2_col2" class="data row2 col2" >3.8848</td>
#       <td id="T_7abbe_row2_col3" class="data row2 col3" >-0.0753</td>
#       <td id="T_7abbe_row2_col4" class="data row2 col4" >0.3375</td>
#       <td id="T_7abbe_row2_col5" class="data row2 col5" >0.3471</td>
#     </tr>
#     <tr>
#       <th id="T_7abbe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7abbe_row3_col0" class="data row3 col0" >3.2102</td>
#       <td id="T_7abbe_row3_col1" class="data row3 col1" >15.4655</td>
#       <td id="T_7abbe_row3_col2" class="data row3 col2" >3.9326</td>
#       <td id="T_7abbe_row3_col3" class="data row3 col3" >-0.1153</td>
#       <td id="T_7abbe_row3_col4" class="data row3 col4" >0.3745</td>
#       <td id="T_7abbe_row3_col5" class="data row3 col5" >0.4046</td>
#     </tr>
#     <tr>
#       <th id="T_7abbe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7abbe_row4_col0" class="data row4 col0" >2.8027</td>
#       <td id="T_7abbe_row4_col1" class="data row4 col1" >13.1933</td>
#       <td id="T_7abbe_row4_col2" class="data row4 col2" >3.6323</td>
#       <td id="T_7abbe_row4_col3" class="data row4 col3" >-0.1652</td>
#       <td id="T_7abbe_row4_col4" class="data row4 col4" >0.3355</td>
#       <td id="T_7abbe_row4_col5" class="data row4 col5" >0.3240</td>
#     </tr>
#     <tr>
#       <th id="T_7abbe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7abbe_row5_col0" class="data row5 col0" >2.6926</td>
#       <td id="T_7abbe_row5_col1" class="data row5 col1" >12.1319</td>
#       <td id="T_7abbe_row5_col2" class="data row5 col2" >3.4831</td>
#       <td id="T_7abbe_row5_col3" class="data row5 col3" >0.1740</td>
#       <td id="T_7abbe_row5_col4" class="data row5 col4" >0.3261</td>
#       <td id="T_7abbe_row5_col5" class="data row5 col5" >0.3211</td>
#     </tr>
#     <tr>
#       <th id="T_7abbe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7abbe_row6_col0" class="data row6 col0" >3.1181</td>
#       <td id="T_7abbe_row6_col1" class="data row6 col1" >16.7058</td>
#       <td id="T_7abbe_row6_col2" class="data row6 col2" >4.0873</td>
#       <td id="T_7abbe_row6_col3" class="data row6 col3" >0.0148</td>
#       <td id="T_7abbe_row6_col4" class="data row6 col4" >0.3678</td>
#       <td id="T_7abbe_row6_col5" class="data row6 col5" >0.3920</td>
#     </tr>
#     <tr>
#       <th id="T_7abbe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7abbe_row7_col0" class="data row7 col0" >3.2399</td>
#       <td id="T_7abbe_row7_col1" class="data row7 col1" >16.7254</td>
#       <td id="T_7abbe_row7_col2" class="data row7 col2" >4.0897</td>
#       <td id="T_7abbe_row7_col3" class="data row7 col3" >0.0215</td>
#       <td id="T_7abbe_row7_col4" class="data row7 col4" >0.3619</td>
#       <td id="T_7abbe_row7_col5" class="data row7 col5" >0.3579</td>
#     </tr>
#     <tr>
#       <th id="T_7abbe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7abbe_row8_col0" class="data row8 col0" >3.1703</td>
#       <td id="T_7abbe_row8_col1" class="data row8 col1" >16.5002</td>
#       <td id="T_7abbe_row8_col2" class="data row8 col2" >4.0620</td>
#       <td id="T_7abbe_row8_col3" class="data row8 col3" >0.0555</td>
#       <td id="T_7abbe_row8_col4" class="data row8 col4" >0.3220</td>
#       <td id="T_7abbe_row8_col5" class="data row8 col5" >0.3020</td>
#     </tr>
#     <tr>
#       <th id="T_7abbe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7abbe_row9_col0" class="data row9 col0" >3.3063</td>
#       <td id="T_7abbe_row9_col1" class="data row9 col1" >16.5939</td>
#       <td id="T_7abbe_row9_col2" class="data row9 col2" >4.0736</td>
#       <td id="T_7abbe_row9_col3" class="data row9 col3" >-0.1735</td>
#       <td id="T_7abbe_row9_col4" class="data row9 col4" >0.3695</td>
#       <td id="T_7abbe_row9_col5" class="data row9 col5" >0.3663</td>
#     </tr>
#     <tr>
#       <th id="T_7abbe_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7abbe_row10_col0" class="data row10 col0" >3.0631</td>
#       <td id="T_7abbe_row10_col1" class="data row10 col1" >14.8772</td>
#       <td id="T_7abbe_row10_col2" class="data row10 col2" >3.8504</td>
#       <td id="T_7abbe_row10_col3" class="data row10 col3" >-0.0160</td>
#       <td id="T_7abbe_row10_col4" class="data row10 col4" >0.3434</td>
#       <td id="T_7abbe_row10_col5" class="data row10 col5" >0.3456</td>
#     </tr>
#     <tr>
#       <th id="T_7abbe_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_7abbe_row11_col0" class="data row11 col0" >0.1890</td>
#       <td id="T_7abbe_row11_col1" class="data row11 col1" >1.7342</td>
#       <td id="T_7abbe_row11_col2" class="data row11 col2" >0.2279</td>
#       <td id="T_7abbe_row11_col3" class="data row11 col3" >0.1064</td>
#       <td id="T_7abbe_row11_col4" class="data row11 col4" >0.0218</td>
#       <td id="T_7abbe_row11_col5" class="data row11 col5" >0.0342</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_rfj = tune_model(rfj)
# Out:
# <style type="text/css">
# #T_2ecd3_row10_col0, #T_2ecd3_row10_col1, #T_2ecd3_row10_col2, #T_2ecd3_row10_col3, #T_2ecd3_row10_col4, #T_2ecd3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2ecd3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ecd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2ecd3_row0_col0" class="data row0 col0" >2.8590</td>
#       <td id="T_2ecd3_row0_col1" class="data row0 col1" >12.7814</td>
#       <td id="T_2ecd3_row0_col2" class="data row0 col2" >3.5751</td>
#       <td id="T_2ecd3_row0_col3" class="data row0 col3" >0.1262</td>
#       <td id="T_2ecd3_row0_col4" class="data row0 col4" >0.3047</td>
#       <td id="T_2ecd3_row0_col5" class="data row0 col5" >0.3005</td>
#     </tr>
#     <tr>
#       <th id="T_2ecd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2ecd3_row1_col0" class="data row1 col0" >2.7754</td>
#       <td id="T_2ecd3_row1_col1" class="data row1 col1" >10.9981</td>
#       <td id="T_2ecd3_row1_col2" class="data row1 col2" >3.3163</td>
#       <td id="T_2ecd3_row1_col3" class="data row1 col3" >0.1646</td>
#       <td id="T_2ecd3_row1_col4" class="data row1 col4" >0.3202</td>
#       <td id="T_2ecd3_row1_col5" class="data row1 col5" >0.3352</td>
#     </tr>
#     <tr>
#       <th id="T_2ecd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2ecd3_row2_col0" class="data row2 col0" >2.9843</td>
#       <td id="T_2ecd3_row2_col1" class="data row2 col1" >13.5652</td>
#       <td id="T_2ecd3_row2_col2" class="data row2 col2" >3.6831</td>
#       <td id="T_2ecd3_row2_col3" class="data row2 col3" >0.0335</td>
#       <td id="T_2ecd3_row2_col4" class="data row2 col4" >0.3210</td>
#       <td id="T_2ecd3_row2_col5" class="data row2 col5" >0.3231</td>
#     </tr>
#     <tr>
#       <th id="T_2ecd3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2ecd3_row3_col0" class="data row3 col0" >2.9925</td>
#       <td id="T_2ecd3_row3_col1" class="data row3 col1" >13.3202</td>
#       <td id="T_2ecd3_row3_col2" class="data row3 col2" >3.6497</td>
#       <td id="T_2ecd3_row3_col3" class="data row3 col3" >0.0394</td>
#       <td id="T_2ecd3_row3_col4" class="data row3 col4" >0.3564</td>
#       <td id="T_2ecd3_row3_col5" class="data row3 col5" >0.3845</td>
#     </tr>
#     <tr>
#       <th id="T_2ecd3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2ecd3_row4_col0" class="data row4 col0" >2.7748</td>
#       <td id="T_2ecd3_row4_col1" class="data row4 col1" >11.9262</td>
#       <td id="T_2ecd3_row4_col2" class="data row4 col2" >3.4534</td>
#       <td id="T_2ecd3_row4_col3" class="data row4 col3" >-0.0533</td>
#       <td id="T_2ecd3_row4_col4" class="data row4 col4" >0.3250</td>
#       <td id="T_2ecd3_row4_col5" class="data row4 col5" >0.3307</td>
#     </tr>
#     <tr>
#       <th id="T_2ecd3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2ecd3_row5_col0" class="data row5 col0" >2.7978</td>
#       <td id="T_2ecd3_row5_col1" class="data row5 col1" >12.4685</td>
#       <td id="T_2ecd3_row5_col2" class="data row5 col2" >3.5311</td>
#       <td id="T_2ecd3_row5_col3" class="data row5 col3" >0.1511</td>
#       <td id="T_2ecd3_row5_col4" class="data row5 col4" >0.3217</td>
#       <td id="T_2ecd3_row5_col5" class="data row5 col5" >0.3197</td>
#     </tr>
#     <tr>
#       <th id="T_2ecd3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2ecd3_row6_col0" class="data row6 col0" >2.9844</td>
#       <td id="T_2ecd3_row6_col1" class="data row6 col1" >15.5164</td>
#       <td id="T_2ecd3_row6_col2" class="data row6 col2" >3.9391</td>
#       <td id="T_2ecd3_row6_col3" class="data row6 col3" >0.0849</td>
#       <td id="T_2ecd3_row6_col4" class="data row6 col4" >0.3549</td>
#       <td id="T_2ecd3_row6_col5" class="data row6 col5" >0.3748</td>
#     </tr>
#     <tr>
#       <th id="T_2ecd3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2ecd3_row7_col0" class="data row7 col0" >3.1795</td>
#       <td id="T_2ecd3_row7_col1" class="data row7 col1" >14.7003</td>
#       <td id="T_2ecd3_row7_col2" class="data row7 col2" >3.8341</td>
#       <td id="T_2ecd3_row7_col3" class="data row7 col3" >0.1400</td>
#       <td id="T_2ecd3_row7_col4" class="data row7 col4" >0.3413</td>
#       <td id="T_2ecd3_row7_col5" class="data row7 col5" >0.3583</td>
#     </tr>
#     <tr>
#       <th id="T_2ecd3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2ecd3_row8_col0" class="data row8 col0" >3.1290</td>
#       <td id="T_2ecd3_row8_col1" class="data row8 col1" >15.9328</td>
#       <td id="T_2ecd3_row8_col2" class="data row8 col2" >3.9916</td>
#       <td id="T_2ecd3_row8_col3" class="data row8 col3" >0.0879</td>
#       <td id="T_2ecd3_row8_col4" class="data row8 col4" >0.3206</td>
#       <td id="T_2ecd3_row8_col5" class="data row8 col5" >0.3078</td>
#     </tr>
#     <tr>
#       <th id="T_2ecd3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2ecd3_row9_col0" class="data row9 col0" >3.0071</td>
#       <td id="T_2ecd3_row9_col1" class="data row9 col1" >13.6306</td>
#       <td id="T_2ecd3_row9_col2" class="data row9 col2" >3.6920</td>
#       <td id="T_2ecd3_row9_col3" class="data row9 col3" >0.0361</td>
#       <td id="T_2ecd3_row9_col4" class="data row9 col4" >0.3339</td>
#       <td id="T_2ecd3_row9_col5" class="data row9 col5" >0.3397</td>
#     </tr>
#     <tr>
#       <th id="T_2ecd3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2ecd3_row10_col0" class="data row10 col0" >2.9484</td>
#       <td id="T_2ecd3_row10_col1" class="data row10 col1" >13.4840</td>
#       <td id="T_2ecd3_row10_col2" class="data row10 col2" >3.6665</td>
#       <td id="T_2ecd3_row10_col3" class="data row10 col3" >0.0810</td>
#       <td id="T_2ecd3_row10_col4" class="data row10 col4" >0.3300</td>
#       <td id="T_2ecd3_row10_col5" class="data row10 col5" >0.3374</td>
#     </tr>
#     <tr>
#       <th id="T_2ecd3_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_2ecd3_row11_col0" class="data row11 col0" >0.1359</td>
#       <td id="T_2ecd3_row11_col1" class="data row11 col1" >1.4762</td>
#       <td id="T_2ecd3_row11_col2" class="data row11 col2" >0.2010</td>
#       <td id="T_2ecd3_row11_col3" class="data row11 col3" >0.0644</td>
#       <td id="T_2ecd3_row11_col4" class="data row11 col4" >0.0157</td>
#       <td id="T_2ecd3_row11_col5" class="data row11 col5" >0.0262</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_rfj
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='log2', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.005,
#                       min_impurity_split=None, min_samples_leaf=2,
#                       min_samples_split=10, min_weight_fraction_leaf=0.0,
#                       n_estimators=190, n_jobs=-1, oob_score=False,
#                       random_state=8301, verbose=0, warm_start=False)

# %%
predict_model(tuned_rfj)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5c4c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5c4c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5c4c_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_f5c4c_row0_col1" class="data row0 col1" >2.9253</td>
#       <td id="T_f5c4c_row0_col2" class="data row0 col2" >13.7597</td>
#       <td id="T_f5c4c_row0_col3" class="data row0 col3" >3.7094</td>
#       <td id="T_f5c4c_row0_col4" class="data row0 col4" >0.1305</td>
#       <td id="T_f5c4c_row0_col5" class="data row0 col5" >0.3294</td>
#       <td id="T_f5c4c_row0_col6" class="data row0 col6" >0.3313</td>
#     </tr>
#   </tbody>
# </table>
#         DayMo     Month      Year   festivo  Quincena  Dayw_Friday  \
# 0   -0.662421  0.298207  0.282680 -0.219496 -0.251337    -0.390455
# 1    1.627810  0.005255 -0.679728 -0.219496  3.978717    -0.390455
# 2   -1.005956 -0.873602  0.282680 -0.219496 -0.251337    -0.390455
# 3    0.940740  1.470017 -0.679728 -0.219496 -0.251337    -0.390455
# 4    1.055252 -1.459507 -0.679728 -0.219496 -0.251337    -0.390455
# ..        ...       ...       ...       ...       ...          ...
# 378 -0.662421  1.470017  1.245088 -0.219496 -0.251337    -0.390455
# 379 -0.891444  1.470017 -0.679728  4.555886 -0.251337    -0.390455
# 380 -0.891444  1.177064  0.282680 -0.219496 -0.251337    -0.390455
# 381 -0.662421 -1.459507  1.245088 -0.219496 -0.251337     2.561117
# 382  0.024648  0.884112  1.245088  4.555886 -0.251337    -0.390455
#
#      Dayw_Monday  Dayw_Saturday  Dayw_Sunday  Dayw_Thursday  Dayw_Tuesday  \
# 0      -0.403699      -0.422298    -0.416754      -0.401819     -0.388546
# 1      -0.403699      -0.422298    -0.416754       2.488684     -0.388546
# 2      -0.403699      -0.422298    -0.416754       2.488684     -0.388546
# 3      -0.403699      -0.422298    -0.416754       2.488684     -0.388546
# 4      -0.403699      -0.422298    -0.416754      -0.401819     -0.388546
# ..           ...            ...          ...            ...           ...
# 378    -0.403699      -0.422298     2.399495      -0.401819     -0.388546
# 379    -0.403699      -0.422298    -0.416754      -0.401819      2.573700
# 380    -0.403699      -0.422298    -0.416754      -0.401819      2.573700
# 381    -0.403699      -0.422298    -0.416754      -0.401819     -0.388546
# 382     2.477095      -0.422298    -0.416754      -0.401819     -0.388546
#
#      Dayw_Wednesday  Total      Label
# 0          2.307865   15.0  11.417809
# 1         -0.433301   10.0  11.399860
# 2         -0.433301   10.0  11.388690
# 3         -0.433301   18.0  11.381095
# 4          2.307865   20.0  11.625775
# ..              ...    ...        ...
# 378       -0.433301    3.0  10.224995
# 379       -0.433301   14.0   9.442640
# 380       -0.433301   10.0  11.277705
# 381       -0.433301   15.0  10.526226
# 382       -0.433301    9.0   8.696846
#
# [383 rows x 14 columns]

# %%
labeltr = DfTrain['Total']
labeltest = DfTest['Total']
DfTrain = DfTrain.drop('Total', axis = 1)
DfTest = DfTest.drop('Total', axis = 1)

# %%
forest = tuned_rfj.fit(DfTrain,labeltr)

# %% [markdown]
# ## Rmse entrenamiento

# %%
ypredTrain = forest.predict(DfTrain)

# %%
(mse(ypredTrain,labeltr))**(1/2)
# Out:
# 3.4613361333844774

# %% [markdown]
# ## Rmse Test

# %%
ypredTest = forest.predict(DfTest)

# %%
(mse(ypredTest,labeltest))**(1/2)
# Out:
# 3.4445540593756245

# %% [markdown]
# ## Rmse Evaluación

# %%
labelevalua = Dfevalua['Total']

# %%
Dfevalua = Dfevalua.drop(['Total'], axis = 1)

# %%
yevalua = forest.predict(Dfevalua)

# %%
(mse(yevalua,labelevalua))**(1/2)
# Out:
# 5.265937402314841

# %% [markdown]
# ## Se guarda modelo

# %%
joblib.dump(forest, 'modelo_Atropello_entrenado.pkl') # Se guarda el modelo.
# Out:
# ['modelo_Atropello_entrenado.pkl']
