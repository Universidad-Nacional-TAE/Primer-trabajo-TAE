# %%
import pandas as pd
import numpy as np

# %%
from pycaret.regression import *

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error as mse

# %%
import joblib

# %%
ChoqueTrain = pd.read_csv('Choque_train.csv', encoding = 'utf-8')
ChoqueTest = pd.read_csv('Choque_test.csv', encoding = 'utf-8')
Choqueevalua = pd.read_csv('Choque_evalua.csv', encoding = 'utf-8')

# %%
Choqueevalua.head()
# Out:
#   FECHA_ACCIDENTE  Total
# 0      2020-01-01     39
# 1      2020-01-02     51
# 2      2020-01-03     71
# 3      2020-01-04     59
# 4      2020-01-05     46

# %%
df_festivos = pd.read_csv('festivosm.csv', encoding = 'utf-8', sep =';')

# %%
df_festivos['Fecha'] = pd.to_datetime(df_festivos['Fecha'], format="%m/%d/%Y")

# %%
ChoqueTrain['FECHA_ACCIDENTE'] = pd.to_datetime(ChoqueTrain['FECHA_ACCIDENTE'], format="%Y/%m/%d")
ChoqueTest['FECHA_ACCIDENTE'] = pd.to_datetime(ChoqueTest['FECHA_ACCIDENTE'], format="%Y/%m/%d")
Choqueevalua['FECHA_ACCIDENTE'] = pd.to_datetime(Choqueevalua['FECHA_ACCIDENTE'], format="%Y/%m/%d")

# %%
ChoqueTrain['festivo'] = ChoqueTrain['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)
ChoqueTest['festivo'] = ChoqueTest['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)
Choqueevalua['festivo'] = Choqueevalua['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)

# %%
ChoqueTrain['Year'] = ChoqueTrain['FECHA_ACCIDENTE'].dt.year
ChoqueTrain['Month'] = ChoqueTrain['FECHA_ACCIDENTE'].dt.month
ChoqueTrain['DayMo'] = ChoqueTrain['FECHA_ACCIDENTE'].dt.day
ChoqueTrain['Dayw'] = ChoqueTrain['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
ChoqueTest['Year'] = ChoqueTest['FECHA_ACCIDENTE'].dt.year
ChoqueTest['Month'] = ChoqueTest['FECHA_ACCIDENTE'].dt.month
ChoqueTest['DayMo'] = ChoqueTest['FECHA_ACCIDENTE'].dt.day
ChoqueTest['Dayw'] = ChoqueTest['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
Choqueevalua['Year'] = Choqueevalua['FECHA_ACCIDENTE'].dt.year
Choqueevalua['Month'] = Choqueevalua['FECHA_ACCIDENTE'].dt.month
Choqueevalua['DayMo'] = Choqueevalua['FECHA_ACCIDENTE'].dt.day
Choqueevalua['Dayw'] = Choqueevalua['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
Choqueevalua.head()
# Out:
#   FECHA_ACCIDENTE  Total  festivo  Year  Month  DayMo       Dayw
# 0      2020-01-01     39        1  2020      1      1  Wednesday
# 1      2020-01-02     51        0  2020      1      2   Thursday
# 2      2020-01-03     71        0  2020      1      3     Friday
# 3      2020-01-04     59        0  2020      1      4   Saturday
# 4      2020-01-05     46        0  2020      1      5     Sunday

# %%
def quincena(f):
    z = []
    for i,j in zip(f['DayMo'],f['Dayw']):
        if (i in [15,30,31] and j in ['Monday','Tuesday', 'Thursday', 'Friday','Wednesday']):
            z.append(1)
        else:
            z.append(0)
    return z

# %%
ChoqueTrain['Quincena'] = quincena(ChoqueTrain)
ChoqueTest['Quincena'] = quincena(ChoqueTest)
Choqueevalua['Quincena'] = quincena(Choqueevalua)

# %%
variab = ['DayMo','Month','Year','festivo','Dayw','Total','Quincena']

# %%
ChoqueTrain = ChoqueTrain[variab]
ChoqueTest = ChoqueTest[variab]
Choqueevalua = Choqueevalua[variab]

# %%
Choqueevalua.head()
# Out:
#    DayMo  Month  Year  festivo       Dayw  Total  Quincena
# 0      1      1  2020        1  Wednesday     39         0
# 1      2      1  2020        0   Thursday     51         0
# 2      3      1  2020        0     Friday     71         0
# 3      4      1  2020        0   Saturday     59         0
# 4      5      1  2020        0     Sunday     46         0

# %% [markdown]
# # One hot encoding

# %%
ChoqueTrain = pd.get_dummies(ChoqueTrain)
ChoqueTest = pd.get_dummies(ChoqueTest)
Choqueevalua = pd.get_dummies(Choqueevalua)

# %%
num = list(ChoqueTrain.columns.values)
num.remove('Total')

# %%
exp_reg101 = setup(data = ChoqueTrain, target = 'Total',
                   numeric_features = num , normalize = True, session_id = 8301)
# Out:
# <style type="text/css">
# #T_733d3_row27_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_733d3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_733d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_733d3_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_733d3_row0_col1" class="data row0 col1" >8301</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_733d3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_733d3_row1_col1" class="data row1 col1" >Total</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_733d3_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_733d3_row2_col1" class="data row2 col1" >(1277, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_733d3_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_733d3_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_733d3_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_733d3_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_733d3_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_733d3_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_733d3_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_733d3_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_733d3_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_733d3_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_733d3_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_733d3_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_733d3_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_733d3_row9_col1" class="data row9 col1" >(893, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_733d3_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_733d3_row10_col1" class="data row10 col1" >(384, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_733d3_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_733d3_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_733d3_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_733d3_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_733d3_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_733d3_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_733d3_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_733d3_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_733d3_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_733d3_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_733d3_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_733d3_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_733d3_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_733d3_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_733d3_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_733d3_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_733d3_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_733d3_row19_col1" class="data row19 col1" >cc44</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_733d3_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_733d3_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_733d3_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_733d3_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_733d3_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_733d3_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_733d3_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_733d3_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_733d3_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_733d3_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_733d3_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_733d3_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_733d3_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_733d3_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_733d3_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_733d3_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_733d3_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_733d3_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_733d3_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_733d3_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_733d3_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_733d3_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_733d3_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_8b218_ th {
#   text-align: left;
# }
# #T_8b218_row0_col0, #T_8b218_row0_col5, #T_8b218_row0_col6, #T_8b218_row1_col0, #T_8b218_row1_col1, #T_8b218_row1_col2, #T_8b218_row1_col3, #T_8b218_row1_col4, #T_8b218_row1_col5, #T_8b218_row2_col0, #T_8b218_row2_col1, #T_8b218_row2_col2, #T_8b218_row2_col3, #T_8b218_row2_col4, #T_8b218_row2_col6, #T_8b218_row3_col0, #T_8b218_row3_col1, #T_8b218_row3_col2, #T_8b218_row3_col3, #T_8b218_row3_col4, #T_8b218_row3_col5, #T_8b218_row3_col6, #T_8b218_row4_col0, #T_8b218_row4_col1, #T_8b218_row4_col2, #T_8b218_row4_col3, #T_8b218_row4_col4, #T_8b218_row4_col5, #T_8b218_row4_col6, #T_8b218_row5_col0, #T_8b218_row5_col1, #T_8b218_row5_col2, #T_8b218_row5_col3, #T_8b218_row5_col4, #T_8b218_row5_col5, #T_8b218_row5_col6, #T_8b218_row6_col0, #T_8b218_row6_col1, #T_8b218_row6_col2, #T_8b218_row6_col3, #T_8b218_row6_col4, #T_8b218_row6_col5, #T_8b218_row6_col6, #T_8b218_row7_col0, #T_8b218_row7_col1, #T_8b218_row7_col2, #T_8b218_row7_col3, #T_8b218_row7_col4, #T_8b218_row7_col5, #T_8b218_row7_col6, #T_8b218_row8_col0, #T_8b218_row8_col1, #T_8b218_row8_col2, #T_8b218_row8_col3, #T_8b218_row8_col4, #T_8b218_row8_col5, #T_8b218_row8_col6, #T_8b218_row9_col0, #T_8b218_row9_col1, #T_8b218_row9_col2, #T_8b218_row9_col3, #T_8b218_row9_col4, #T_8b218_row9_col5, #T_8b218_row9_col6, #T_8b218_row10_col0, #T_8b218_row10_col1, #T_8b218_row10_col2, #T_8b218_row10_col3, #T_8b218_row10_col4, #T_8b218_row10_col5, #T_8b218_row10_col6, #T_8b218_row11_col0, #T_8b218_row11_col1, #T_8b218_row11_col2, #T_8b218_row11_col3, #T_8b218_row11_col4, #T_8b218_row11_col5, #T_8b218_row11_col6, #T_8b218_row12_col0, #T_8b218_row12_col1, #T_8b218_row12_col2, #T_8b218_row12_col3, #T_8b218_row12_col4, #T_8b218_row12_col5, #T_8b218_row12_col6, #T_8b218_row13_col0, #T_8b218_row13_col1, #T_8b218_row13_col2, #T_8b218_row13_col3, #T_8b218_row13_col4, #T_8b218_row13_col5, #T_8b218_row13_col6, #T_8b218_row14_col0, #T_8b218_row14_col1, #T_8b218_row14_col2, #T_8b218_row14_col3, #T_8b218_row14_col4, #T_8b218_row14_col5, #T_8b218_row14_col6, #T_8b218_row15_col0, #T_8b218_row15_col1, #T_8b218_row15_col2, #T_8b218_row15_col3, #T_8b218_row15_col4, #T_8b218_row15_col5, #T_8b218_row15_col6, #T_8b218_row16_col0, #T_8b218_row16_col1, #T_8b218_row16_col2, #T_8b218_row16_col3, #T_8b218_row16_col4, #T_8b218_row16_col5, #T_8b218_row16_col6, #T_8b218_row17_col0, #T_8b218_row17_col1, #T_8b218_row17_col2, #T_8b218_row17_col3, #T_8b218_row17_col4, #T_8b218_row17_col5, #T_8b218_row17_col6, #T_8b218_row18_col0, #T_8b218_row18_col1, #T_8b218_row18_col2, #T_8b218_row18_col3, #T_8b218_row18_col4, #T_8b218_row18_col5, #T_8b218_row18_col6 {
#   text-align: left;
# }
# #T_8b218_row0_col1, #T_8b218_row0_col2, #T_8b218_row0_col3, #T_8b218_row0_col4, #T_8b218_row1_col6, #T_8b218_row2_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8b218_row0_col7, #T_8b218_row1_col7, #T_8b218_row2_col7, #T_8b218_row3_col7, #T_8b218_row4_col7, #T_8b218_row5_col7, #T_8b218_row6_col7, #T_8b218_row7_col7, #T_8b218_row8_col7, #T_8b218_row9_col7, #T_8b218_row10_col7, #T_8b218_row11_col7, #T_8b218_row12_col7, #T_8b218_row13_col7, #T_8b218_row14_col7, #T_8b218_row15_col7, #T_8b218_row16_col7, #T_8b218_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8b218_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8b218_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b218_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_8b218_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_8b218_row0_col1" class="data row0 col1" >9.5048</td>
#       <td id="T_8b218_row0_col2" class="data row0 col2" >146.9733</td>
#       <td id="T_8b218_row0_col3" class="data row0 col3" >12.0825</td>
#       <td id="T_8b218_row0_col4" class="data row0 col4" >0.6781</td>
#       <td id="T_8b218_row0_col5" class="data row0 col5" >0.1714</td>
#       <td id="T_8b218_row0_col6" class="data row0 col6" >0.1358</td>
#       <td id="T_8b218_row0_col7" class="data row0 col7" >0.0670</td>
#     </tr>
#     <tr>
#       <th id="T_8b218_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_8b218_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_8b218_row1_col1" class="data row1 col1" >9.5532</td>
#       <td id="T_8b218_row1_col2" class="data row1 col2" >147.0877</td>
#       <td id="T_8b218_row1_col3" class="data row1 col3" >12.1004</td>
#       <td id="T_8b218_row1_col4" class="data row1 col4" >0.6755</td>
#       <td id="T_8b218_row1_col5" class="data row1 col5" >0.1685</td>
#       <td id="T_8b218_row1_col6" class="data row1 col6" >0.1354</td>
#       <td id="T_8b218_row1_col7" class="data row1 col7" >0.5580</td>
#     </tr>
#     <tr>
#       <th id="T_8b218_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_8b218_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8b218_row2_col1" class="data row2 col1" >9.6873</td>
#       <td id="T_8b218_row2_col2" class="data row2 col2" >150.0586</td>
#       <td id="T_8b218_row2_col3" class="data row2 col3" >12.2253</td>
#       <td id="T_8b218_row2_col4" class="data row2 col4" >0.6679</td>
#       <td id="T_8b218_row2_col5" class="data row2 col5" >0.1675</td>
#       <td id="T_8b218_row2_col6" class="data row2 col6" >0.1364</td>
#       <td id="T_8b218_row2_col7" class="data row2 col7" >0.6880</td>
#     </tr>
#     <tr>
#       <th id="T_8b218_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_8b218_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_8b218_row3_col1" class="data row3 col1" >9.6694</td>
#       <td id="T_8b218_row3_col2" class="data row3 col2" >152.6163</td>
#       <td id="T_8b218_row3_col3" class="data row3 col3" >12.3083</td>
#       <td id="T_8b218_row3_col4" class="data row3 col4" >0.6641</td>
#       <td id="T_8b218_row3_col5" class="data row3 col5" >0.1705</td>
#       <td id="T_8b218_row3_col6" class="data row3 col6" >0.1367</td>
#       <td id="T_8b218_row3_col7" class="data row3 col7" >0.2630</td>
#     </tr>
#     <tr>
#       <th id="T_8b218_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_8b218_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_8b218_row4_col1" class="data row4 col1" >9.7865</td>
#       <td id="T_8b218_row4_col2" class="data row4 col2" >157.9228</td>
#       <td id="T_8b218_row4_col3" class="data row4 col3" >12.5235</td>
#       <td id="T_8b218_row4_col4" class="data row4 col4" >0.6536</td>
#       <td id="T_8b218_row4_col5" class="data row4 col5" >0.1767</td>
#       <td id="T_8b218_row4_col6" class="data row4 col6" >0.1391</td>
#       <td id="T_8b218_row4_col7" class="data row4 col7" >0.2450</td>
#     </tr>
#     <tr>
#       <th id="T_8b218_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_8b218_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_8b218_row5_col1" class="data row5 col1" >10.1609</td>
#       <td id="T_8b218_row5_col2" class="data row5 col2" >171.5932</td>
#       <td id="T_8b218_row5_col3" class="data row5 col3" >13.0525</td>
#       <td id="T_8b218_row5_col4" class="data row5 col4" >0.6285</td>
#       <td id="T_8b218_row5_col5" class="data row5 col5" >0.2347</td>
#       <td id="T_8b218_row5_col6" class="data row5 col6" >0.1500</td>
#       <td id="T_8b218_row5_col7" class="data row5 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_8b218_level0_row6" class
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=8301, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
rfj = create_model('rf')
# Out:
# <style type="text/css">
# #T_dffb4_row10_col0, #T_dffb4_row10_col1, #T_dffb4_row10_col2, #T_dffb4_row10_col3, #T_dffb4_row10_col4, #T_dffb4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_dffb4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dffb4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dffb4_row0_col0" class="data row0 col0" >9.5159</td>
#       <td id="T_dffb4_row0_col1" class="data row0 col1" >147.0853</td>
#       <td id="T_dffb4_row0_col2" class="data row0 col2" >12.1279</td>
#       <td id="T_dffb4_row0_col3" class="data row0 col3" >0.6976</td>
#       <td id="T_dffb4_row0_col4" class="data row0 col4" >0.1613</td>
#       <td id="T_dffb4_row0_col5" class="data row0 col5" >0.1281</td>
#     </tr>
#     <tr>
#       <th id="T_dffb4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dffb4_row1_col0" class="data row1 col0" >11.2729</td>
#       <td id="T_dffb4_row1_col1" class="data row1 col1" >221.5942</td>
#       <td id="T_dffb4_row1_col2" class="data row1 col2" >14.8860</td>
#       <td id="T_dffb4_row1_col3" class="data row1 col3" >0.4644</td>
#       <td id="T_dffb4_row1_col4" class="data row1 col4" >0.1972</td>
#       <td id="T_dffb4_row1_col5" class="data row1 col5" >0.1507</td>
#     </tr>
#     <tr>
#       <th id="T_dffb4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dffb4_row2_col0" class="data row2 col0" >8.9489</td>
#       <td id="T_dffb4_row2_col1" class="data row2 col1" >131.1445</td>
#       <td id="T_dffb4_row2_col2" class="data row2 col2" >11.4518</td>
#       <td id="T_dffb4_row2_col3" class="data row2 col3" >0.7408</td>
#       <td id="T_dffb4_row2_col4" class="data row2 col4" >0.1693</td>
#       <td id="T_dffb4_row2_col5" class="data row2 col5" >0.1367</td>
#     </tr>
#     <tr>
#       <th id="T_dffb4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dffb4_row3_col0" class="data row3 col0" >9.7875</td>
#       <td id="T_dffb4_row3_col1" class="data row3 col1" >154.1344</td>
#       <td id="T_dffb4_row3_col2" class="data row3 col2" >12.4151</td>
#       <td id="T_dffb4_row3_col3" class="data row3 col3" >0.6892</td>
#       <td id="T_dffb4_row3_col4" class="data row3 col4" >0.1615</td>
#       <td id="T_dffb4_row3_col5" class="data row3 col5" >0.1325</td>
#     </tr>
#     <tr>
#       <th id="T_dffb4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dffb4_row4_col0" class="data row4 col0" >10.8826</td>
#       <td id="T_dffb4_row4_col1" class="data row4 col1" >171.7288</td>
#       <td id="T_dffb4_row4_col2" class="data row4 col2" >13.1045</td>
#       <td id="T_dffb4_row4_col3" class="data row4 col3" >0.6494</td>
#       <td id="T_dffb4_row4_col4" class="data row4 col4" >0.1642</td>
#       <td id="T_dffb4_row4_col5" class="data row4 col5" >0.1408</td>
#     </tr>
#     <tr>
#       <th id="T_dffb4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dffb4_row5_col0" class="data row5 col0" >8.9533</td>
#       <td id="T_dffb4_row5_col1" class="data row5 col1" >125.2920</td>
#       <td id="T_dffb4_row5_col2" class="data row5 col2" >11.1934</td>
#       <td id="T_dffb4_row5_col3" class="data row5 col3" >0.7546</td>
#       <td id="T_dffb4_row5_col4" class="data row5 col4" >0.1559</td>
#       <td id="T_dffb4_row5_col5" class="data row5 col5" >0.1293</td>
#     </tr>
#     <tr>
#       <th id="T_dffb4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dffb4_row6_col0" class="data row6 col0" >9.2549</td>
#       <td id="T_dffb4_row6_col1" class="data row6 col1" >160.5808</td>
#       <td id="T_dffb4_row6_col2" class="data row6 col2" >12.6720</td>
#       <td id="T_dffb4_row6_col3" class="data row6 col3" >0.6584</td>
#       <td id="T_dffb4_row6_col4" class="data row6 col4" >0.1950</td>
#       <td id="T_dffb4_row6_col5" class="data row6 col5" >0.1449</td>
#     </tr>
#     <tr>
#       <th id="T_dffb4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dffb4_row7_col0" class="data row7 col0" >9.3947</td>
#       <td id="T_dffb4_row7_col1" class="data row7 col1" >154.4960</td>
#       <td id="T_dffb4_row7_col2" class="data row7 col2" >12.4296</td>
#       <td id="T_dffb4_row7_col3" class="data row7 col3" >0.7077</td>
#       <td id="T_dffb4_row7_col4" class="data row7 col4" >0.2004</td>
#       <td id="T_dffb4_row7_col5" class="data row7 col5" >0.1571</td>
#     </tr>
#     <tr>
#       <th id="T_dffb4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dffb4_row8_col0" class="data row8 col0" >9.1457</td>
#       <td id="T_dffb4_row8_col1" class="data row8 col1" >124.0891</td>
#       <td id="T_dffb4_row8_col2" class="data row8 col2" >11.1395</td>
#       <td id="T_dffb4_row8_col3" class="data row8 col3" >0.5814</td>
#       <td id="T_dffb4_row8_col4" class="data row8 col4" >0.1521</td>
#       <td id="T_dffb4_row8_col5" class="data row8 col5" >0.1207</td>
#     </tr>
#     <tr>
#       <th id="T_dffb4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dffb4_row9_col0" class="data row9 col0" >9.5378</td>
#       <td id="T_dffb4_row9_col1" class="data row9 col1" >136.0174</td>
#       <td id="T_dffb4_row9_col2" class="data row9 col2" >11.6626</td>
#       <td id="T_dffb4_row9_col3" class="data row9 col3" >0.6977</td>
#       <td id="T_dffb4_row9_col4" class="data row9 col4" >0.1480</td>
#       <td id="T_dffb4_row9_col5" class="data row9 col5" >0.1263</td>
#     </tr>
#     <tr>
#       <th id="T_dffb4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_dffb4_row10_col0" class="data row10 col0" >9.6694</td>
#       <td id="T_dffb4_row10_col1" class="data row10 col1" >152.6163</td>
#       <td id="T_dffb4_row10_col2" class="data row10 col2" >12.3083</td>
#       <td id="T_dffb4_row10_col3" class="data row10 col3" >0.6641</td>
#       <td id="T_dffb4_row10_col4" class="data row10 col4" >0.1705</td>
#       <td id="T_dffb4_row10_col5" class="data row10 col5" >0.1367</td>
#     </tr>
#     <tr>
#       <th id="T_dffb4_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_dffb4_row11_col0" class="data row11 col0" >0.7518</td>
#       <td id="T_dffb4_row11_col1" class="data row11 col1" >27.4228</td>
#       <td id="T_dffb4_row11_col2" class="data row11 col2" >1.0597</td>
#       <td id="T_dffb4_row11_col3" class="data row11 col3" >0.0811</td>
#       <td id="T_dffb4_row11_col4" class="data row11 col4" >0.0186</td>
#       <td id="T_dffb4_row11_col5" class="data row11 col5" >0.0110</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_rfj = tune_model(rfj)
# Out:
# <style type="text/css">
# #T_fc52b_row10_col0, #T_fc52b_row10_col1, #T_fc52b_row10_col2, #T_fc52b_row10_col3, #T_fc52b_row10_col4, #T_fc52b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_fc52b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc52b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc52b_row0_col0" class="data row0 col0" >9.3782</td>
#       <td id="T_fc52b_row0_col1" class="data row0 col1" >133.8598</td>
#       <td id="T_fc52b_row0_col2" class="data row0 col2" >11.5698</td>
#       <td id="T_fc52b_row0_col3" class="data row0 col3" >0.7248</td>
#       <td id="T_fc52b_row0_col4" class="data row0 col4" >0.1561</td>
#       <td id="T_fc52b_row0_col5" class="data row0 col5" >0.1288</td>
#     </tr>
#     <tr>
#       <th id="T_fc52b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc52b_row1_col0" class="data row1 col0" >9.8975</td>
#       <td id="T_fc52b_row1_col1" class="data row1 col1" >157.0753</td>
#       <td id="T_fc52b_row1_col2" class="data row1 col2" >12.5330</td>
#       <td id="T_fc52b_row1_col3" class="data row1 col3" >0.6204</td>
#       <td id="T_fc52b_row1_col4" class="data row1 col4" >0.1684</td>
#       <td id="T_fc52b_row1_col5" class="data row1 col5" >0.1358</td>
#     </tr>
#     <tr>
#       <th id="T_fc52b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc52b_row2_col0" class="data row2 col0" >9.7812</td>
#       <td id="T_fc52b_row2_col1" class="data row2 col1" >149.9653</td>
#       <td id="T_fc52b_row2_col2" class="data row2 col2" >12.2460</td>
#       <td id="T_fc52b_row2_col3" class="data row2 col3" >0.7036</td>
#       <td id="T_fc52b_row2_col4" class="data row2 col4" >0.1773</td>
#       <td id="T_fc52b_row2_col5" class="data row2 col5" >0.1453</td>
#     </tr>
#     <tr>
#       <th id="T_fc52b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc52b_row3_col0" class="data row3 col0" >9.7209</td>
#       <td id="T_fc52b_row3_col1" class="data row3 col1" >145.6558</td>
#       <td id="T_fc52b_row3_col2" class="data row3 col2" >12.0688</td>
#       <td id="T_fc52b_row3_col3" class="data row3 col3" >0.7063</td>
#       <td id="T_fc52b_row3_col4" class="data row3 col4" >0.1650</td>
#       <td id="T_fc52b_row3_col5" class="data row3 col5" >0.1381</td>
#     </tr>
#     <tr>
#       <th id="T_fc52b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc52b_row4_col0" class="data row4 col0" >11.2096</td>
#       <td id="T_fc52b_row4_col1" class="data row4 col1" >175.9882</td>
#       <td id="T_fc52b_row4_col2" class="data row4 col2" >13.2661</td>
#       <td id="T_fc52b_row4_col3" class="data row4 col3" >0.6408</td>
#       <td id="T_fc52b_row4_col4" class="data row4 col4" >0.1698</td>
#       <td id="T_fc52b_row4_col5" class="data row4 col5" >0.1494</td>
#     </tr>
#     <tr>
#       <th id="T_fc52b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc52b_row5_col0" class="data row5 col0" >10.2730</td>
#       <td id="T_fc52b_row5_col1" class="data row5 col1" >170.0783</td>
#       <td id="T_fc52b_row5_col2" class="data row5 col2" >13.0414</td>
#       <td id="T_fc52b_row5_col3" class="data row5 col3" >0.6669</td>
#       <td id="T_fc52b_row5_col4" class="data row5 col4" >0.2021</td>
#       <td id="T_fc52b_row5_col5" class="data row5 col5" >0.1639</td>
#     </tr>
#     <tr>
#       <th id="T_fc52b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fc52b_row6_col0" class="data row6 col0" >9.9312</td>
#       <td id="T_fc52b_row6_col1" class="data row6 col1" >184.1046</td>
#       <td id="T_fc52b_row6_col2" class="data row6 col2" >13.5685</td>
#       <td id="T_fc52b_row6_col3" class="data row6 col3" >0.6084</td>
#       <td id="T_fc52b_row6_col4" class="data row6 col4" >0.2139</td>
#       <td id="T_fc52b_row6_col5" class="data row6 col5" >0.1636</td>
#     </tr>
#     <tr>
#       <th id="T_fc52b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fc52b_row7_col0" class="data row7 col0" >10.2576</td>
#       <td id="T_fc52b_row7_col1" class="data row7 col1" >193.0380</td>
#       <td id="T_fc52b_row7_col2" class="data row7 col2" >13.8938</td>
#       <td id="T_fc52b_row7_col3" class="data row7 col3" >0.6348</td>
#       <td id="T_fc52b_row7_col4" class="data row7 col4" >0.2332</td>
#       <td id="T_fc52b_row7_col5" class="data row7 col5" >0.1830</td>
#     </tr>
#     <tr>
#       <th id="T_fc52b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fc52b_row8_col0" class="data row8 col0" >8.9505</td>
#       <td id="T_fc52b_row8_col1" class="data row8 col1" >125.9216</td>
#       <td id="T_fc52b_row8_col2" class="data row8 col2" >11.2215</td>
#       <td id="T_fc52b_row8_col3" class="data row8 col3" >0.5753</td>
#       <td id="T_fc52b_row8_col4" class="data row8 col4" >0.1518</td>
#       <td id="T_fc52b_row8_col5" class="data row8 col5" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_fc52b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fc52b_row9_col0" class="data row9 col0" >9.9580</td>
#       <td id="T_fc52b_row9_col1" class="data row9 col1" >143.3731</td>
#       <td id="T_fc52b_row9_col2" class="data row9 col2" >11.9739</td>
#       <td id="T_fc52b_row9_col3" class="data row9 col3" >0.6814</td>
#       <td id="T_fc52b_row9_col4" class="data row9 col4" >0.1608</td>
#       <td id="T_fc52b_row9_col5" class="data row9 col5" >0.1375</td>
#     </tr>
#     <tr>
#       <th id="T_fc52b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_fc52b_row10_col0" class="data row10 col0" >9.9358</td>
#       <td id="T_fc52b_row10_col1" class="data row10 col1" >157.9060</td>
#       <td id="T_fc52b_row10_col2" class="data row10 col2" >12.5383</td>
#       <td id="T_fc52b_row10_col3" class="data row10 col3" >0.6562</td>
#       <td id="T_fc52b_row10_col4" class="data row10 col4" >0.1798</td>
#       <td id="T_fc52b_row10_col5" class="data row10 col5" >0.1463</td>
#     </tr>
#     <tr>
#       <th id="T_fc52b_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_fc52b_row11_col0" class="data row11 col0" >0.5651</td>
#       <td id="T_fc52b_row11_col1" class="data row11 col1" >21.0285</td>
#       <td id="T_fc52b_row11_col2" class="data row11 col2" >0.8353</td>
#       <td id="T_fc52b_row11_col3" class="data row11 col3" >0.0458</td>
#       <td id="T_fc52b_row11_col4" class="data row11 col4" >0.0258</td>
#       <td id="T_fc52b_row11_col5" class="data row11 col5" >0.0183</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_rfj
# Out:
# RandomForestRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                       max_depth=9, max_features='log2', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.4,
#                       min_impurity_split=None, min_samples_leaf=2,
#                       min_samples_split=7, min_weight_fraction_leaf=0.0,
#                       n_estimators=80, n_jobs=-1, oob_score=False,
#                       random_state=8301, verbose=0, warm_start=False)

# %%
predict_model(tuned_rfj)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0e8d1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e8d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e8d1_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_0e8d1_row0_col1" class="data row0 col1" >9.9656</td>
#       <td id="T_0e8d1_row0_col2" class="data row0 col2" >161.1876</td>
#       <td id="T_0e8d1_row0_col3" class="data row0 col3" >12.6960</td>
#       <td id="T_0e8d1_row0_col4" class="data row0 col4" >0.6321</td>
#       <td id="T_0e8d1_row0_col5" class="data row0 col5" >0.1819</td>
#       <td id="T_0e8d1_row0_col6" class="data row0 col6" >0.1465</td>
#     </tr>
#   </tbody>
# </table>
#         DayMo     Month      Year   festivo  Quincena  Dayw_Friday  \
# 0   -0.655115  0.285810  1.236388 -0.213699 -0.227653     -0.41648
# 1    1.188913 -1.779622  0.273795 -0.213699 -0.227653     -0.41648
# 2   -1.116122  1.170995  0.273795 -0.213699 -0.227653     -0.41648
# 3    0.036395 -0.304313 -0.688798 -0.213699 -0.227653     -0.41648
# 4   -0.194108 -1.779622  1.236388 -0.213699 -0.227653     -0.41648
# ..        ...       ...       ...       ...       ...          ...
# 379 -0.309360  0.580872  1.236388 -0.213699 -0.227653     -0.41648
# 380  0.036395  0.285810  0.273795 -0.213699 -0.227653     -0.41648
# 381  1.534668 -0.304313  0.273795 -0.213699 -0.227653     -0.41648
# 382 -0.885619  1.466057 -0.688798  4.679470 -0.227653     -0.41648
# 383  1.188913  0.580872 -0.688798 -0.213699 -0.227653     -0.41648
#
#      Dayw_Monday  Dayw_Saturday  Dayw_Sunday  Dayw_Thursday  Dayw_Tuesday  \
# 0      -0.397789      -0.434835    -0.422019       2.550333     -0.412771
# 1      -0.397789      -0.434835    -0.422019      -0.392106      2.422650
# 2      -0.397789      -0.434835     2.369560      -0.392106     -0.412771
# 3      -0.397789      -0.434835    -0.422019      -0.392106      2.422650
# 4      -0.397789       2.299724    -0.422019      -0.392106     -0.412771
# ..           ...            ...          ...            ...           ...
# 379    -0.397789      -0.434835    -0.422019      -0.392106     -0.412771
# 380    -0.397789      -0.434835    -0.422019      -0.392106      2.422650
# 381    -0.397789      -0.434835    -0.422019      -0.392106     -0.412771
# 382    -0.397789      -0.434835    -0.422019      -0.392106      2.422650
# 383    -0.397789       2.299724    -0.422019      -0.392106     -0.412771
#
#      Dayw_Wednesday  Total      Label
# 0          -0.38062   87.0  87.288566
# 1          -0.38062   83.0  83.771580
# 2          -0.38062   49.0  46.221061
# 3          -0.38062   98.0  89.472354
# 4          -0.38062   80.0  74.374451
# ..              ...    ...        ...
# 379         2.62729   81.0  87.524023
# 380        -0.38062   97.0  89.490966
# 381         2.62729   75.0  86.036221
# 382        -0.38062   66.0  59.994366
# 383        -0.38062   77.0  80.787960
#
# [384 rows x 14 columns]

# %%
labeltr = ChoqueTrain['Total']
labeltest = ChoqueTest['Total']
ChoqueTrain = ChoqueTrain.drop('Total', axis = 1)
ChoqueTest = ChoqueTest.drop('Total', axis = 1)

# %%
forest = tuned_rfj.fit(ChoqueTrain,labeltr)

# %% [markdown]
# ## Rmse para el cojunto de entrenamiento.

# %%
ypredTrain = forest.predict(ChoqueTrain)

# %%
(mse(ypredTrain,labeltr))**(1/2)
# Out:
# 11.92663384614956

# %% [markdown]
# ## Rmse para el test.

# %%
ypredTest = forest.predict(ChoqueTest)

# %%
(mse(ypredTest,labeltest))**(1/2)
# Out:
# 13.289767138439892

# %% [markdown]
# ## Modelo en evaluación

# %%
labelevalua = Choqueevalua['Total']

# %%
Choqueevalua = Choqueevalua.drop(['Total'], axis = 1)

# %%
yevalua = forest.predict(Choqueevalua)

# %%
(mse(yevalua,labelevalua))**(1/2)
# Out:
# 40.872946356819604

# %% [markdown]
# ## Se guarda el modelo

# %%
joblib.dump(forest, 'modelo_choque_entrenado.pkl') # Se guarda el modelo.
