# %%
import pandas as pd
import numpy as np
from pycaret.regression import *
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error as mse
import joblib

# %%
DfTrain = pd.read_csv('Caida_train.csv', encoding = 'utf-8')
DfTest = pd.read_csv('Caida_test.csv', encoding = 'utf-8')
Dfevalua = pd.read_csv('Caida_evalua.csv', encoding = 'utf-8')

# %%
DfTest.head()
# Out:
#   FECHA_ACCIDENTE  Total
# 0      2018-01-01      7
# 1      2018-01-02     11
# 2      2018-01-03      4
# 3      2018-01-04     12
# 4      2018-01-05     11

# %%
df_festivos = pd.read_csv('festivosm.csv', encoding = 'utf-8', sep =';')

# %%
df_festivos['Fecha'] = pd.to_datetime(df_festivos['Fecha'], format="%m/%d/%Y")

# %%
DfTrain['FECHA_ACCIDENTE'] = pd.to_datetime(DfTrain['FECHA_ACCIDENTE'], format="%Y/%m/%d")
DfTest['FECHA_ACCIDENTE'] = pd.to_datetime(DfTest['FECHA_ACCIDENTE'], format="%Y/%m/%d")
Dfevalua['FECHA_ACCIDENTE'] = pd.to_datetime(Dfevalua['FECHA_ACCIDENTE'], format="%Y/%m/%d")

# %%
DfTrain['festivo'] = DfTrain['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)
DfTest['festivo'] = DfTest['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)
Dfevalua['festivo'] = Dfevalua['FECHA_ACCIDENTE'].apply(lambda x: 1 if x in df_festivos['Fecha'].unique() else 0)

# %%
DfTrain['Year'] = DfTrain['FECHA_ACCIDENTE'].dt.year
DfTrain['Month'] = DfTrain['FECHA_ACCIDENTE'].dt.month
DfTrain['DayMo'] = DfTrain['FECHA_ACCIDENTE'].dt.day
DfTrain['Dayw'] = DfTrain['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
DfTest['Year'] = DfTest['FECHA_ACCIDENTE'].dt.year
DfTest['Month'] = DfTest['FECHA_ACCIDENTE'].dt.month
DfTest['DayMo'] = DfTest['FECHA_ACCIDENTE'].dt.day
DfTest['Dayw'] = DfTest['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
Dfevalua['Year'] = Dfevalua['FECHA_ACCIDENTE'].dt.year
Dfevalua['Month'] = Dfevalua['FECHA_ACCIDENTE'].dt.month
Dfevalua['DayMo'] = Dfevalua['FECHA_ACCIDENTE'].dt.day
Dfevalua['Dayw'] = Dfevalua['FECHA_ACCIDENTE'].apply(lambda x: x.strftime('%A'))

# %%
DfTest.head()
# Out:
#   FECHA_ACCIDENTE  Total  festivo  Year  Month  DayMo       Dayw
# 0      2018-01-01      7        1  2018      1      1     Monday
# 1      2018-01-02     11        0  2018      1      2    Tuesday
# 2      2018-01-03      4        0  2018      1      3  Wednesday
# 3      2018-01-04     12        0  2018      1      4   Thursday
# 4      2018-01-05     11        0  2018      1      5     Friday

# %%
def quincena(f):
    z = []
    for i,j in zip(f['DayMo'],f['Dayw']):
        if (i in [15,30,31] and j in ['Monday','Tuesday', 'Thursday', 'Friday','Wednesday']):
            z.append(1)
        else:
            z.append(0)
    return z

# %%
DfTrain['Quincena'] = quincena(DfTrain)
DfTest['Quincena'] = quincena(DfTest)
Dfevalua['Quincena'] = quincena(Dfevalua)

# %%
variab = ['DayMo','Month','Year','festivo','Dayw','Total','Quincena']

# %%
DfTrain = DfTrain[variab]
DfTest = DfTest[variab]
Dfevalua = Dfevalua[variab]

# %%
Dfevalua.head()
# Out:
#    DayMo  Month  Year  festivo       Dayw  Total  Quincena
# 0      1      1  2020        1  Wednesday      8         0
# 1      2      1  2020        0   Thursday     14         0
# 2      3      1  2020        0     Friday     12         0
# 3      4      1  2020        0   Saturday      7         0
# 4      5      1  2020        0     Sunday      7         0

# %% [markdown]
# ## One hot encoding y Modelo

# %%
DfTrain = pd.get_dummies(DfTrain)
DfTest = pd.get_dummies(DfTest)
Dfevalua = pd.get_dummies(Dfevalua)

# %%
num = list(DfTrain.columns.values)
num.remove('Total')

# %%
exp_reg101 = setup(data = DfTrain, target = 'Total',
                   numeric_features = num , normalize = True, session_id = 8301)
# Out:
# <style type="text/css">
# #T_d1a98_row27_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d1a98_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1a98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1a98_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d1a98_row0_col1" class="data row0 col1" >8301</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d1a98_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d1a98_row1_col1" class="data row1 col1" >Total</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d1a98_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_d1a98_row2_col1" class="data row2 col1" >(1275, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d1a98_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_d1a98_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d1a98_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_d1a98_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d1a98_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_d1a98_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d1a98_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_d1a98_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d1a98_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_d1a98_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d1a98_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_d1a98_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d1a98_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_d1a98_row9_col1" class="data row9 col1" >(892, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d1a98_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_d1a98_row10_col1" class="data row10 col1" >(383, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d1a98_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_d1a98_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d1a98_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_d1a98_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d1a98_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_d1a98_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d1a98_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_d1a98_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d1a98_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_d1a98_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d1a98_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_d1a98_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d1a98_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_d1a98_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d1a98_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_d1a98_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d1a98_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_d1a98_row19_col1" class="data row19 col1" >6b6e</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d1a98_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_d1a98_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d1a98_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_d1a98_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d1a98_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_d1a98_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d1a98_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_d1a98_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d1a98_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_d1a98_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_d1a98_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_d1a98_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_d1a98_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_d1a98_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_d1a98_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_d1a98_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_d1a98_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_d1a98_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_d1a98_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_d1a98_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d1a98_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_d1a98_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_d1a98_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T
>0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_79d5d_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_79d5d_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_79d5d_row3_col1" class="data row3 col1" >3.0752</td>
#       <td id="T_79d5d_row3_col2" class="data row3 col2" >15.4234</td>
#       <td id="T_79d5d_row3_col3" class="data row3 col3" >3.9165</td>
#       <td id="T_79d5d_row3_col4" class="data row3 col4" >0.0991</td>
#       <td id="T_79d5d_row3_col5" class="data row3 col5" >0.3842</td>
#       <td id="T_79d5d_row3_col6" class="data row3 col6" >0.4161</td>
#       <td id="T_79d5d_row3_col7" class="data row3 col7" >1.4590</td>
#     </tr>
#     <tr>
#       <th id="T_79d5d_level0_row4" class="row_heading level0 row4" >huber</th>
#       <td id="T_79d5d_row4_col0" class="data row4 col0" >Huber Regressor</td>
#       <td id="T_79d5d_row4_col1" class="data row4 col1" >3.0749</td>
#       <td id="T_79d5d_row4_col2" class="data row4 col2" >15.5160</td>
#       <td id="T_79d5d_row4_col3" class="data row4 col3" >3.9285</td>
#       <td id="T_79d5d_row4_col4" class="data row4 col4" >0.0934</td>
#       <td id="T_79d5d_row4_col5" class="data row4 col5" >0.3818</td>
#       <td id="T_79d5d_row4_col6" class="data row4 col6" >0.4063</td>
#       <td id="T_79d5d_row4_col7" class="data row4 col7" >0.0150</td>
#     </tr>
#     <tr>
#       <th id="T_79d5d_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_79d5d_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_79d5d_row5_col1" class="data row5 col1" >3.1156</td>
#       <td id="T_79d5d_row5_col2" class="data row5 col2" >15.9932</td>
#       <td id="T_79d5d_row5_col3" class="data row5 col3" >3.9909</td>
#       <td id="T_79d5d_row5_col4" class="data row5 col4" >0.0619</td>
#       <td id="T_79d5d_row5_col5" class="data row5 col5" >0.3876</td>
#       <td id="T_79d5d_row5_col6" class="data row5 col6" >0.4132</td>
#       <td id="T_79d5d_row5_col7" class="data row5 col7" >0.0850</td>
#     </tr>
#     <tr>
#       <th id="T_79d5d_level0_row6" class="row_heading level0 row6" >omp</th>
#       <td
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False)

# %%
rfj = create_model('rf')
# Out:
# <style type="text/css">
# #T_16d20_row10_col0, #T_16d20_row10_col1, #T_16d20_row10_col2, #T_16d20_row10_col3, #T_16d20_row10_col4, #T_16d20_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_16d20_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16d20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16d20_row0_col0" class="data row0 col0" >2.9151</td>
#       <td id="T_16d20_row0_col1" class="data row0 col1" >14.0151</td>
#       <td id="T_16d20_row0_col2" class="data row0 col2" >3.7437</td>
#       <td id="T_16d20_row0_col3" class="data row0 col3" >0.0638</td>
#       <td id="T_16d20_row0_col4" class="data row0 col4" >0.3459</td>
#       <td id="T_16d20_row0_col5" class="data row0 col5" >0.3216</td>
#     </tr>
#     <tr>
#       <th id="T_16d20_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16d20_row1_col0" class="data row1 col0" >3.4460</td>
#       <td id="T_16d20_row1_col1" class="data row1 col1" >18.5931</td>
#       <td id="T_16d20_row1_col2" class="data row1 col2" >4.3120</td>
#       <td id="T_16d20_row1_col3" class="data row1 col3" >0.1475</td>
#       <td id="T_16d20_row1_col4" class="data row1 col4" >0.3956</td>
#       <td id="T_16d20_row1_col5" class="data row1 col5" >0.4228</td>
#     </tr>
#     <tr>
#       <th id="T_16d20_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16d20_row2_col0" class="data row2 col0" >3.1509</td>
#       <td id="T_16d20_row2_col1" class="data row2 col1" >15.7617</td>
#       <td id="T_16d20_row2_col2" class="data row2 col2" >3.9701</td>
#       <td id="T_16d20_row2_col3" class="data row2 col3" >0.0496</td>
#       <td id="T_16d20_row2_col4" class="data row2 col4" >0.3986</td>
#       <td id="T_16d20_row2_col5" class="data row2 col5" >0.4375</td>
#     </tr>
#     <tr>
#       <th id="T_16d20_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16d20_row3_col0" class="data row3 col0" >2.8563</td>
#       <td id="T_16d20_row3_col1" class="data row3 col1" >14.9834</td>
#       <td id="T_16d20_row3_col2" class="data row3 col2" >3.8708</td>
#       <td id="T_16d20_row3_col3" class="data row3 col3" >-0.0431</td>
#       <td id="T_16d20_row3_col4" class="data row3 col4" >0.3368</td>
#       <td id="T_16d20_row3_col5" class="data row3 col5" >0.3152</td>
#     </tr>
#     <tr>
#       <th id="T_16d20_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16d20_row4_col0" class="data row4 col0" >3.1208</td>
#       <td id="T_16d20_row4_col1" class="data row4 col1" >15.0096</td>
#       <td id="T_16d20_row4_col2" class="data row4 col2" >3.8742</td>
#       <td id="T_16d20_row4_col3" class="data row4 col3" >-0.0194</td>
#       <td id="T_16d20_row4_col4" class="data row4 col4" >0.4121</td>
#       <td id="T_16d20_row4_col5" class="data row4 col5" >0.4745</td>
#     </tr>
#     <tr>
#       <th id="T_16d20_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_16d20_row5_col0" class="data row5 col0" >3.0289</td>
#       <td id="T_16d20_row5_col1" class="data row5 col1" >15.7810</td>
#       <td id="T_16d20_row5_col2" class="data row5 col2" >3.9725</td>
#       <td id="T_16d20_row5_col3" class="data row5 col3" >-0.0116</td>
#       <td id="T_16d20_row5_col4" class="data row5 col4" >0.3817</td>
#       <td id="T_16d20_row5_col5" class="data row5 col5" >0.3818</td>
#     </tr>
#     <tr>
#       <th id="T_16d20_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_16d20_row6_col0" class="data row6 col0" >3.4416</td>
#       <td id="T_16d20_row6_col1" class="data row6 col1" >20.8648</td>
#       <td id="T_16d20_row6_col2" class="data row6 col2" >4.5678</td>
#       <td id="T_16d20_row6_col3" class="data row6 col3" >0.1301</td>
#       <td id="T_16d20_row6_col4" class="data row6 col4" >0.4103</td>
#       <td id="T_16d20_row6_col5" class="data row6 col5" >0.4230</td>
#     </tr>
#     <tr>
#       <th id="T_16d20_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_16d20_row7_col0" class="data row7 col0" >3.2628</td>
#       <td id="T_16d20_row7_col1" class="data row7 col1" >17.4150</td>
#       <td id="T_16d20_row7_col2" class="data row7 col2" >4.1731</td>
#       <td id="T_16d20_row7_col3" class="data row7 col3" >0.0510</td>
#       <td id="T_16d20_row7_col4" class="data row7 col4" >0.4623</td>
#       <td id="T_16d20_row7_col5" class="data row7 col5" >0.5613</td>
#     </tr>
#     <tr>
#       <th id="T_16d20_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_16d20_row8_col0" class="data row8 col0" >3.0880</td>
#       <td id="T_16d20_row8_col1" class="data row8 col1" >14.3282</td>
#       <td id="T_16d20_row8_col2" class="data row8 col2" >3.7853</td>
#       <td id="T_16d20_row8_col3" class="data row8 col3" >0.0101</td>
#       <td id="T_16d20_row8_col4" class="data row8 col4" >0.3803</td>
#       <td id="T_16d20_row8_col5" class="data row8 col5" >0.4220</td>
#     </tr>
#     <tr>
#       <th id="T_16d20_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_16d20_row9_col0" class="data row9 col0" >3.5643</td>
#       <td id="T_16d20_row9_col1" class="data row9 col1" >19.0795</td>
#       <td id="T_16d20_row9_col2" class="data row9 col2" >4.3680</td>
#       <td id="T_16d20_row9_col3" class="data row9 col3" >-0.0976</td>
#       <td id="T_16d20_row9_col4" class="data row9 col4" >0.4369</td>
#       <td id="T_16d20_row9_col5" class="data row9 col5" >0.5045</td>
#     </tr>
#     <tr>
#       <th id="T_16d20_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_16d20_row10_col0" class="data row10 col0" >3.1875</td>
#       <td id="T_16d20_row10_col1" class="data row10 col1" >16.5832</td>
#       <td id="T_16d20_row10_col2" class="data row10 col2" >4.0638</td>
#       <td id="T_16d20_row10_col3" class="data row10 col3" >0.0280</td>
#       <td id="T_16d20_row10_col4" class="data row10 col4" >0.3961</td>
#       <td id="T_16d20_row10_col5" class="data row10 col5" >0.4264</td>
#     </tr>
#     <tr>
#       <th id="T_16d20_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_16d20_row11_col0" class="data row11 col0" >0.2244</td>
#       <td id="T_16d20_row11_col1" class="data row11 col1" >2.1755</td>
#       <td id="T_16d20_row11_col2" class="data row11 col2" >0.2628</td>
#       <td id="T_16d20_row11_col3" class="data row11 col3" >0.0721</td>
#       <td id="T_16d20_row11_col4" class="data row11 col4" >0.0361</td>
#       <td id="T_16d20_row11_col5" class="data row11 col5" >0.0722</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_rfj = tune_model(rfj)
# Out:
# <style type="text/css">
# #T_290cb_row10_col0, #T_290cb_row10_col1, #T_290cb_row10_col2, #T_290cb_row10_col3, #T_290cb_row10_col4, #T_290cb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_290cb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_290cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_290cb_row0_col0" class="data row0 col0" >2.8156</td>
#       <td id="T_290cb_row0_col1" class="data row0 col1" >12.5277</td>
#       <td id="T_290cb_row0_col2" class="data row0 col2" >3.5394</td>
#       <td id="T_290cb_row0_col3" class="data row0 col3" >0.1631</td>
#       <td id="T_290cb_row0_col4" class="data row0 col4" >0.3299</td>
#       <td id="T_290cb_row0_col5" class="data row0 col5" >0.3266</td>
#     </tr>
#     <tr>
#       <th id="T_290cb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_290cb_row1_col0" class="data row1 col0" >3.4080</td>
#       <td id="T_290cb_row1_col1" class="data row1 col1" >18.6841</td>
#       <td id="T_290cb_row1_col2" class="data row1 col2" >4.3225</td>
#       <td id="T_290cb_row1_col3" class="data row1 col3" >0.1433</td>
#       <td id="T_290cb_row1_col4" class="data row1 col4" >0.3935</td>
#       <td id="T_290cb_row1_col5" class="data row1 col5" >0.4171</td>
#     </tr>
#     <tr>
#       <th id="T_290cb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_290cb_row2_col0" class="data row2 col0" >3.0298</td>
#       <td id="T_290cb_row2_col1" class="data row2 col1" >14.9770</td>
#       <td id="T_290cb_row2_col2" class="data row2 col2" >3.8700</td>
#       <td id="T_290cb_row2_col3" class="data row2 col3" >0.0969</td>
#       <td id="T_290cb_row2_col4" class="data row2 col4" >0.3867</td>
#       <td id="T_290cb_row2_col5" class="data row2 col5" >0.4252</td>
#     </tr>
#     <tr>
#       <th id="T_290cb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_290cb_row3_col0" class="data row3 col0" >2.7447</td>
#       <td id="T_290cb_row3_col1" class="data row3 col1" >13.5821</td>
#       <td id="T_290cb_row3_col2" class="data row3 col2" >3.6854</td>
#       <td id="T_290cb_row3_col3" class="data row3 col3" >0.0544</td>
#       <td id="T_290cb_row3_col4" class="data row3 col4" >0.3203</td>
#       <td id="T_290cb_row3_col5" class="data row3 col5" >0.3073</td>
#     </tr>
#     <tr>
#       <th id="T_290cb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_290cb_row4_col0" class="data row4 col0" >2.9845</td>
#       <td id="T_290cb_row4_col1" class="data row4 col1" >13.7349</td>
#       <td id="T_290cb_row4_col2" class="data row4 col2" >3.7061</td>
#       <td id="T_290cb_row4_col3" class="data row4 col3" >0.0671</td>
#       <td id="T_290cb_row4_col4" class="data row4 col4" >0.3997</td>
#       <td id="T_290cb_row4_col5" class="data row4 col5" >0.4696</td>
#     </tr>
#     <tr>
#       <th id="T_290cb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_290cb_row5_col0" class="data row5 col0" >2.8800</td>
#       <td id="T_290cb_row5_col1" class="data row5 col1" >13.8779</td>
#       <td id="T_290cb_row5_col2" class="data row5 col2" >3.7253</td>
#       <td id="T_290cb_row5_col3" class="data row5 col3" >0.1104</td>
#       <td id="T_290cb_row5_col4" class="data row5 col4" >0.3573</td>
#       <td id="T_290cb_row5_col5" class="data row5 col5" >0.3614</td>
#     </tr>
#     <tr>
#       <th id="T_290cb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_290cb_row6_col0" class="data row6 col0" >3.4866</td>
#       <td id="T_290cb_row6_col1" class="data row6 col1" >21.2597</td>
#       <td id="T_290cb_row6_col2" class="data row6 col2" >4.6108</td>
#       <td id="T_290cb_row6_col3" class="data row6 col3" >0.1137</td>
#       <td id="T_290cb_row6_col4" class="data row6 col4" >0.4137</td>
#       <td id="T_290cb_row6_col5" class="data row6 col5" >0.4339</td>
#     </tr>
#     <tr>
#       <th id="T_290cb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_290cb_row7_col0" class="data row7 col0" >3.2186</td>
#       <td id="T_290cb_row7_col1" class="data row7 col1" >16.2354</td>
#       <td id="T_290cb_row7_col2" class="data row7 col2" >4.0293</td>
#       <td id="T_290cb_row7_col3" class="data row7 col3" >0.1153</td>
#       <td id="T_290cb_row7_col4" class="data row7 col4" >0.4476</td>
#       <td id="T_290cb_row7_col5" class="data row7 col5" >0.5523</td>
#     </tr>
#     <tr>
#       <th id="T_290cb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_290cb_row8_col0" class="data row8 col0" >2.8570</td>
#       <td id="T_290cb_row8_col1" class="data row8 col1" >13.0007</td>
#       <td id="T_290cb_row8_col2" class="data row8 col2" >3.6056</td>
#       <td id="T_290cb_row8_col3" class="data row8 col3" >0.1018</td>
#       <td id="T_290cb_row8_col4" class="data row8 col4" >0.3709</td>
#       <td id="T_290cb_row8_col5" class="data row8 col5" >0.4020</td>
#     </tr>
#     <tr>
#       <th id="T_290cb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_290cb_row9_col0" class="data row9 col0" >3.3485</td>
#       <td id="T_290cb_row9_col1" class="data row9 col1" >16.7313</td>
#       <td id="T_290cb_row9_col2" class="data row9 col2" >4.0904</td>
#       <td id="T_290cb_row9_col3" class="data row9 col3" >0.0375</td>
#       <td id="T_290cb_row9_col4" class="data row9 col4" >0.4194</td>
#       <td id="T_290cb_row9_col5" class="data row9 col5" >0.4861</td>
#     </tr>
#     <tr>
#       <th id="T_290cb_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_290cb_row10_col0" class="data row10 col0" >3.0773</td>
#       <td id="T_290cb_row10_col1" class="data row10 col1" >15.4611</td>
#       <td id="T_290cb_row10_col2" class="data row10 col2" >3.9185</td>
#       <td id="T_290cb_row10_col3" class="data row10 col3" >0.1004</td>
#       <td id="T_290cb_row10_col4" class="data row10 col4" >0.3839</td>
#       <td id="T_290cb_row10_col5" class="data row10 col5" >0.4182</td>
#     </tr>
#     <tr>
#       <th id="T_290cb_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_290cb_row11_col0" class="data row11 col0" >0.2545</td>
#       <td id="T_290cb_row11_col1" class="data row11 col1" >2.6483</td>
#       <td id="T_290cb_row11_col2" class="data row11 col2" >0.3264</td>
#       <td id="T_290cb_row11_col3" class="data row11 col3" >0.0367</td>
#       <td id="T_290cb_row11_col4" class="data row11 col4" >0.0380</td>
#       <td id="T_290cb_row11_col5" class="data row11 col5" >0.0705</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_rfj
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=6, max_features='log2', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.005,
#                       min_impurity_split=None, min_samples_leaf=2,
#                       min_samples_split=10, min_weight_fraction_leaf=0.0,
#                       n_estimators=190, n_jobs=-1, oob_score=False,
#                       random_state=8301, verbose=0, warm_start=False)

# %%
predict_model(tuned_rfj)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ab4cc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab4cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab4cc_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_ab4cc_row0_col1" class="data row0 col1" >3.3113</td>
#       <td id="T_ab4cc_row0_col2" class="data row0 col2" >18.3278</td>
#       <td id="T_ab4cc_row0_col3" class="data row0 col3" >4.2811</td>
#       <td id="T_ab4cc_row0_col4" class="data row0 col4" >0.0707</td>
#       <td id="T_ab4cc_row0_col5" class="data row0 col5" >0.3841</td>
#       <td id="T_ab4cc_row0_col6" class="data row0 col6" >0.3937</td>
#     </tr>
#   </tbody>
# </table>
#         DayMo     Month      Year   festivo  Quincena  Dayw_Friday  \
# 0   -0.558240  0.297406  0.281662 -0.225051 -0.253849    -0.399935
# 1    1.732239  0.004596 -0.680953 -0.225051  3.939355     2.500407
# 2   -0.901812 -0.873836  0.281662 -0.225051 -0.253849     2.500407
# 3    1.045095  1.468649 -0.680953  4.443443 -0.253849     2.500407
# 4    1.045095 -1.459458 -0.680953 -0.225051 -0.253849    -0.399935
# ..        ...       ...       ...       ...       ...          ...
# 378 -0.672764  1.468649  1.244277 -0.225051 -0.253849    -0.399935
# 379 -0.787288  1.468649 -0.680953 -0.225051 -0.253849    -0.399935
# 380 -0.787288  1.175838  0.281662 -0.225051 -0.253849    -0.399935
# 381 -0.558240 -1.459458  1.244277 -0.225051 -0.253849    -0.399935
# 382  0.014380  0.883028  1.244277  4.443443 -0.253849    -0.399935
#
#      Dayw_Monday  Dayw_Saturday  Dayw_Sunday  Dayw_Thursday  Dayw_Tuesday  \
# 0      -0.413042      -0.407447    -0.420453       2.388884     -0.405575
# 1      -0.413042      -0.407447    -0.420453      -0.418606     -0.405575
# 2      -0.413042      -0.407447    -0.420453      -0.418606     -0.405575
# 3      -0.413042      -0.407447    -0.420453      -0.418606     -0.405575
# 4      -0.413042      -0.407447    -0.420453      -0.418606     -0.405575
# ..           ...            ...          ...            ...           ...
# 378    -0.413042      -0.407447     2.378385      -0.418606     -0.405575
# 379    -0.413042      -0.407447    -0.420453      -0.418606     -0.405575
# 380    -0.413042      -0.407447    -0.420453      -0.418606     -0.405575
# 381    -0.413042       2.454307    -0.420453      -0.418606     -0.405575
# 382     2.421062      -0.407447    -0.420453      -0.418606     -0.405575
#
#      Dayw_Wednesday  Total      Label
# 0         -0.392359   18.0  11.825092
# 1         -0.392359    7.0  10.305963
# 2         -0.392359   12.0   9.926635
# 3         -0.392359    3.0   8.594306
# 4          2.548686    7.0  10.541789
# ..              ...    ...        ...
# 378       -0.392359    5.0   7.448042
# 379        2.548686    9.0  10.499437
# 380        2.548686    9.0  10.689385
# 381       -0.392359    9.0   8.736029
# 382       -0.392359    6.0   8.526704
#
# [383 rows x 14 columns]

# %%
labeltr = DfTrain['Total']
labeltest = DfTest['Total']
DfTrain = DfTrain.drop('Total', axis = 1)
DfTest = DfTest.drop('Total', axis = 1)

# %%
forest = tuned_rfj.fit(DfTrain,labeltr)

# %% [markdown]
# ## Rmse entrenamiento

# %%
ypredTrain = forest.predict(DfTrain)

# %%
(mse(ypredTrain,labeltr))**(1/2)
# Out:
# 3.8117078678529572

# %% [markdown]
# ## Rmse Test

# %%
ypredTest = forest.predict(DfTest)

# %%
(mse(ypredTest,labeltest))**(1/2)
# Out:
# 4.119099809065017

# %% [markdown]
# ## Rmse Evaluación

# %%
labelevalua = Dfevalua['Total']

# %%
Dfevalua = Dfevalua.drop(['Total'], axis = 1)

# %%
yevalua = forest.predict(Dfevalua)

# %%
(mse(yevalua,labelevalua))**(1/2)
# Out:
# 5.294891245143799

# %% [markdown]
# ## Se guarda modelo

# %%
joblib.dump(forest, 'modelo_Caida_entrenado.pkl') # Se guarda el modelo.
# Out:
# ['modelo_Caida_entrenado.pkl']
